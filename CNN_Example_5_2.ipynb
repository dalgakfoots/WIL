# %% [markdown]
# ### [예제 5_2] 3 conv / 1 flatten
# #### 3 x 3 x 32,  5 x 5 x 64,  3 x 3 x 128

# %%
# colab 에서 tensorflow 1.x 실행
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime      # datetime.now() 를 이용하여 학습 경과 시간 측정

# read_data_sets() 를 통해 데이터를 객체형태로 받아오고
# one_hot 옵션을 통해 정답(label) 을 one-hot 인코딩된 형태로 받아옴

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

# mnist 데이터 셋은 train, test, validation 3개의 데이터 셋으로 구성되어 있으며.
# num_examples 값을 통해 데이터의 갯수 확인 가능함

print("\n", mnist.train.num_examples, mnist.test.num_examples, mnist.validation.num_examples)

# 데이터는 784(28x28)개의 픽셀을 가지는 이미지와
# 10(0~9)개 클래스를 가지는 one-hot 인코딩된 레이블(정답)을 가지고 있음

print("\ntrain image shape = ", np.shape(mnist.train.images))
print("train label shape = ", np.shape(mnist.train.labels))
print("test image shape = ", np.shape(mnist.test.images))
print("test label shape = ", np.shape(mnist.test.labels))
# Out:
# WARNING:tensorflow:From <ipython-input-2-37edfc5623ff>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
#  55000 10000 5000
#
# train image shape =  (55000, 784)
# train label shape =  (55000, 10)
# test image shape =  (10000, 784)
# test label shape =  (10000, 10)

# %%
# Hyper-Parameter
learning_rate = 0.001  # 학습율
epochs = 50            # 반복횟수
batch_size = 100      # 한번에 입력으로 주어지는 MNIST 개수

# %%
# 입력과 정답을 위한 플레이스홀더 정의
X = tf.placeholder(tf.float32, [None, 784])  

T = tf.placeholder(tf.float32, [None, 10])  

# 입력층의 출력 값. 컨볼루션 연산을 위해 reshape 시킴
A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])   # image 28 X 28 X 1 (black/white)

# %%
# 1번째 컨볼루션 층
# 3X3 크기를 가지는 32개의 필터를 적용

F2 = tf.Variable(tf.random_normal([3, 3, 1, 32], stddev=0.01))  
#b2 = tf.Variable(tf.random_normal([32]))   
b2 = tf.Variable(tf.constant(0.1, shape=[32]))  

# 1번째 컨볼루션 연산을 통해 28 X 28 X1  => 28 X 28 X 32 
C2 = tf.nn.conv2d(A1, F2, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z2 = tf.nn.relu(C2+b2)

# 1번째 max pooling을 통해 28 X 28 X 32  => 14 X 14 X 32 
A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 2번째 컨볼루션 층
F3 = tf.Variable(tf.random_normal([5, 5, 32, 64], stddev=0.01))  
#b3 = tf.Variable(tf.random_normal([64]))   
b3 = tf.Variable(tf.constant(0.1, shape=[64]))  

# 2번째 컨볼루션 연산을 통해 14 X 14 X 32 => 14 X 14 X 64 
C3 = tf.nn.conv2d(A2, F3, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z3 = tf.nn.relu(C3+b3)

# 2번째 max pooling을 통해 14 X 14 X 64 => 7 X 7 X 64
A3 = P3 = tf.nn.max_pool(Z3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 3번째 컨볼루션 층
F4 = tf.Variable(tf.random_normal([3, 3, 64, 128], stddev=0.01))  
#b4 = tf.Variable(tf.random_normal([128]))   
b4 = tf.Variable(tf.constant(0.1, shape=[128]))  

# 3번째 컨볼루션 연산을 통해 7 X 7 X 64 => 7 X 7 X 128
C4 = tf.nn.conv2d(A3, F4, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z4 = tf.nn.relu(C4+b4)

# 3번째 max pooling을 통해 7 X 7 X 128 => 4 X 4 X 128
A4 = P4 = tf.nn.max_pool(Z4, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 4X4 크기를 가진 128개의 activation map을 flatten 시킴
A4_flat = P4_flat = tf.reshape(A4, [-1, 128*4*4])

# %%
# 출력층
W5 = tf.Variable(tf.random_normal([128*4*4, 10], stddev=0.01))
b5 = tf.Variable(tf.random_normal([10]))

# 출력층 선형회귀  값 Z5, 즉 softmax 에 들어가는 입력 값
Z5 = logits = tf.matmul(A4_flat, W5) + b5    # 선형회귀 값 Z5

y = A5 = tf.nn.softmax(Z5)

# %%
loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z5, labels=T) )

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
# batch_size X 10 데이터에 대해 argmax를 통해 행단위로 비교함
predicted_val = tf.equal( tf.argmax(A5, 1), tf.argmax(T, 1) )

# batch_size X 10 의 True, False 를 1 또는 0 으로 변환
accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# index list 출력
accuracy_index = tf.cast(predicted_val, dtype=tf.float32)

# 예측값 처리
predicted_list = tf.argmax(A5, 1)

# %%
index_label_prediction_list = []

with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화
    
    start_time = datetime.now()
    
    for i in range(epochs):    # 30 번 반복수행
        
        total_batch = int(mnist.train.num_examples / batch_size)  # 55,000 / 100

        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
      
            loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})    
        
            if step % 100 == 0:
                print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)             
    
    end_time = datetime.now() 
    
    print("\nelapsed time = ", end_time - start_time) 
    
    # Accuracy 확인
    test_x_data = mnist.test.images    # 10000 X 784
    test_t_data = mnist.test.labels    # 10000 X 10
    
    accuracy_val, predicted_list_val, index_label = sess.run([accuracy, predicted_list, accuracy_index], feed_dict={X: test_x_data, T: test_t_data})
    
    print("\nAccuracy = ", accuracy_val)
    print("type(accuracy_val) = ", type(accuracy_val), ', type(predicted_list_val) = ', type(predicted_list_val), ', type(index_label) = ', type(index_label))
    print("index_label.shape = ", index_label.shape)
    
    index_label_list = list(index_label)
    print("length of index_label_list = ", len(index_label_list))
    print("false label count = ", index_label_list.count([0]))
        
    temp_list = [] 
    
    for index in range(len(index_label)):
        
        if index_label[index] == 0:
            
            temp_list.append(index)
            temp_list.append(np.argmax(test_t_data[index]))  # one-hot encoding 이므로 argmax 로 정답 추출
            temp_list.append(predicted_list_val[index])
            
            index_label_prediction_list.append(temp_list)
            
            temp_list = []
            
    print("\nlength of index_label_false_list", len(index_label_prediction_list))
# Out:
# epochs =  0 , step =  0 , loss_val =  2.9623852
# epochs =  0 , step =  100 , loss_val =  2.30671
# epochs =  0 , step =  200 , loss_val =  0.47174913
# epochs =  0 , step =  300 , loss_val =  0.15746732
# epochs =  0 , step =  400 , loss_val =  0.14371489
# epochs =  0 , step =  500 , loss_val =  0.06854954
# epochs =  1 , step =  0 , loss_val =  0.11527422
# epochs =  1 , step =  100 , loss_val =  0.18936272
# epochs =  1 , step =  200 , loss_val =  0.08018746
# epochs =  1 , step =  300 , loss_val =  0.09892345
# epochs =  1 , step =  400 , loss_val =  0.10095185
# epochs =  1 , step =  500 , loss_val =  0.069808386
# epochs =  2 , step =  0 , loss_val =  0.038401235
# epochs =  2 , step =  100 , loss_val =  0.014873632
# epochs =  2 , step =  200 , loss_val =  0.016417263
# epochs =  2 , step =  300 , loss_val =  0.08921692
# epochs =  2 , step =  400 , loss_val =  0.012925728
# epochs =  2 , step =  500 , loss_val =  0.039875593
# epochs =  3 , step =  0 , loss_val =  0.033159412
# epochs =  3 , step =  100 , loss_val =  0.03151459
# epochs =  3 , step =  200 , loss_val =  0.0372398
# epochs =  3 , step =  300 , loss_val =  0.018090382
# epochs =  3 , step =  400 , loss_val =  0.054416027
# epochs =  3 , step =  500 , loss_val =  0.05393737
# epochs =  4 , step =  0 , loss_val =  0.008946809
# epochs =  4 , step =  100 , loss_val =  0.0038431745
# epochs =  4 , step =  200 , loss_val =  0.025797203
# epochs =  4 , step =  300 , loss_val =  0.031801295
# epochs =  4 , step =  400 , loss_val =  0.0091837095
# epochs =  4 , step =  500 , loss_val =  0.009976701
# epochs =  5 , step =  0 , loss_val =  0.0012602529
# epochs =  5 , step =  100 , loss_val =  0.017997999
# epochs =  5 , step =  200 , loss_val =  0.017810337
# epochs =  5 , step =  300 , loss_val =  0.008111188
# epochs =  5 , step =  400 , loss_val =  0.02020745
# epochs =  5 , step =  500 , loss_val =  0.0026003045
# epochs =  6 , step =  0 , loss_val =  0.01085441
# epochs =  6 , step =  100 , loss_val =  0.0018668276
# epochs =  6 , step =  200 , loss_val =  0.003703897
# epochs =  6 , step =  300 , loss_val =  0.0016722358
# epochs =  6 , step =  400 , loss_val =  0.079022706
# epochs =  6 , step =  500 , loss_val =  0.0026389007
# epochs =  7 , step =  0 , loss_val =  0.00048824016
# epochs =  7 , step =  100 , loss_val =  0.008449259
# epochs =  7 , step =  200 , loss_val =  0.024205327
# epochs =  7 , step =  300 , loss_val =  0.038969778
# epochs =  7 , step =  400 , loss_val =  0.0030371665
# epochs =  7 , step =  500 , loss_val =  0.007760171
# epochs =  8 , step =  0 , loss_val =  0.0061367345
# epochs =  8 , step =  100 , loss_val =  0.008706955
# epochs =  8 , step =  200 , loss_val =  0.012013558
# epochs =  8 , step =  300 , loss_val =  0.0067737917
# epochs =  8 , step =  400 , loss_val =  0.002270092
# epochs =  8 , step =  500 , loss_val =  0.0033452364
# epochs =  9 , step =  0 , loss_val =  0.02146111
# epochs =  9 , step =  100 , loss_val =  0.0012117038
# epochs =  9 , step =  200 , loss_val =  0.0022387009
# epochs =  9 , step =  300 , loss_val =  0.08975987
# epochs =  9 , step =  400 , loss_val =  0.04749042
# epochs =  9 , step =  500 , loss_val =  0.015339569
# epochs =  10 , step =  0 , loss_val =  0.00042891898
# epochs =  10 , step =  100 , loss_val =  0.002305513
# epochs =  10 , step =  200 , loss_val =  0.005964264
# epochs =  10 , step =  300 , loss_val =  0.0016158669
# epochs =  10 , step =  400 , loss_val =  0.0130678415
# epochs =  10 , step =  500 , loss_val =  0.0033855357
# epochs =  11 , step =  0 , loss_val =  0.0038081107
# epochs =  11 , step =  100 , loss_val =  0.00014213768
# epochs =  11 , step =  200 , loss_val =  0.02691882
# epochs =  11 , step =  300 , loss_val =  0.00012197152
# epochs =  11 , step =  400 , loss_val =  0.0030922936
# epochs =  11 , step =  500 , loss_val =  0.0014770633
# epochs =  12 , step =  0 , loss_val =  0.010033741
# epochs =  12 , step =  100 , loss_val =  0.00832772
# epochs =  12 , step =  200 , loss_val =  0.011031733
# epochs =  12 , step =  300 , loss_val =  0.0197146
# epochs =  12 , step =  400 , loss_val =  0.016830675
# epochs =  12 , step =  500 , loss_val =  0.003933309
# epochs =  13 , step =  0 , loss_val =  0.0008445984
# epochs =  13 , step =  100 , loss_val =  0.02161927
# epochs =  13 , step =  200 , loss_val =  0.00041186833
# epochs =  13 , step =  300 , loss_val =  0.014962988
# epochs =  13 , step =  400 , loss_val =  0.0030879623
# epochs =  13 , step =  500 , loss_val =  0.013419527
# epochs =  14 , step =  0 , loss_val =  0.0044509466
# epochs =  14 , step =  100 , loss_val =  0.00053972844
# epochs =  14 , step =  200 , loss_val =  0.00022083249
# epochs =  14 , step =  300 , loss_val =  0.026927607
# epochs =  14 , step =  400 , loss_val =  1.1119772e-05
# epochs =  14 , step =  500 , loss_val =  0.007182239
# epochs =  15 , step =  0 , loss_val =  0.0021432566
# epochs =  15 , step =  100 , loss_val =  0.00034067742
# epochs =  15 , step =  200 , loss_val =  0.008849316
# epochs =  15 , step =  300 , loss_val =  0.00013134065
# epochs =  15 , step =  400 , loss_val =  0.00044240765
# epochs =  15 , step =  500 , loss_val =  0.00013080038
# epochs =  16 , step =  0 , loss_val =  0.038462076
# epochs =  16 , step =  100 , loss_val =  0.0005118926
# epochs =  16 , step =  200 , loss_val =  0.013339883
# epochs =  16 , step =  300 , loss_val =  3.2936212e-05
# epochs =  16 , step =  400 , loss_val =  0.00029333532
# epochs =  16 , step =  500 , loss_val =  0.0012923608
# epochs =  17 , step =  0 , loss_val =  0.00089593127
# epochs =  17 , step =  100 , loss_val =  0.0002499407
# epochs =  17 , step =  200 , loss_val =  0.014513871
# epochs =  17 , step =  300 , loss_val =  0.003946324
# epochs =  17 , step =  400 , loss_val =  0.0014425985
# epochs =  17 , step =  500 , loss_val =  0.004447687
# epochs =  18 , step =  0 , loss_val =  0.0057707173
# epochs =  18 , step =  100 , loss_val =  0.0008000668
# epochs =  18 , step =  200 , loss_val =  0.00011395462
# epochs =  18 , step =  300 , loss_val =  0.00029327715
# epochs =  18 , step =  400 , loss_val =  0.051680144
# epochs =  18 , step =  500 , loss_val =  0.00080437935
# epochs =  19 , step =  0 , loss_val =  0.00090531574
# epochs =  19 , step =  100 , loss_val =  0.0002918148
# epochs =  19 , step =  200 , loss_val =  0.0015724732
# epochs =  19 , step =  300 , loss_val =  0.0003335311
# epochs =  19 , step =  400 , loss_val =  0.010947808
# epochs =  19 , step =  500 , loss_val =  0.00017414807
# epochs =  20 , step =  0 , loss_val =  0.00057257025
# epochs =  20 , step =  100 , loss_val =  1.8248038e-05
# epochs =  20 , step =  200 , loss_val =  4.182701e-05
# epochs =  20 , step =  300 , loss_val =  0.0031308539
# epochs =  20 , step =  400 , loss_val =  0.0001565285
# epochs =  20 , step =  500 , loss_val =  0.00057515217
# epochs =  21 , step =  0 , loss_val =  9.154335e-05
# epochs =  21 , step =  100 , loss_val =  0.00018934032
# epochs =  21 , step =  200 , loss_val =  3.568781e-05
# epochs =  21 , step =  300 , loss_val =  7.126892e-05
# epochs =  21 , step =  400 , loss_val =  0.0076908753
# epochs =  21 , step =  500 , loss_val =  1.6986793e-05
# epochs =  22 , step =  0 , loss_val =  3.3003314e-05
# epochs =  22 , step =  100 , loss_val =  0.00050921174
# epochs =  22 , step =  200 , loss_val =  0.00012763147
# epochs =  22 , step =  300 , loss_val =  6.46011e-05
# epochs =  22 , step =  400 , loss_val =  0.0066729947
# epochs =  22 , step =  500 , loss_val =  0.008623335
# epochs =  23 , step =  0 , loss_val =  0.012070656
# epochs =  23 , step =  100 , loss_val =  1.1742673e-05
# epochs =  23 , step =  200 , loss_val =  2.3387383e-05
# epochs =  23 , step =  300 , loss_val =  8.032693e-05
# epochs =  23 , step =  400 , loss_val =  0.00055548333
# epochs =  23 , step =  500 , loss_val =  0.00012723012
# epochs =  24 , step =  0 , loss_val =  0.012448924
# epochs =  24 , step =  100 , loss_val =  3.5762642e-07
# epochs =  24 , step =  200 , loss_val =  1.5334415e-05
# epochs =  24 , step =  300 , loss_val =  2.2561664e-05
# epochs =  24 , step =  400 , loss_val =  8.4471685e-05
# epochs =  24 , step =  500 , loss_val =  1.3188529e-05
# epochs =  25 , step =  0 , loss_val =  4.553752e-07
# epochs =  25 , step =  100 , loss_val =  0.0002549995
# epochs =  25 , step =  200 , loss_val =  0.00332011
# epochs =  25 , step =  300 , loss_val =  6.5306245e-05
# epochs =  25 , step =  400 , loss_val =  6.576489e-05
# epochs =  25 , step =  500 , loss_val =  9.453286e-05
# epochs =  26 , step =  0 , loss_val =  7.912782e-06
# epochs =  26 , step =  100 , loss_val =  0.020050349
# epochs =  26 , step =  200 , loss_val =  0.00033733505
# epochs =  26 , step =  300 , loss_val =  2.3371424e-05
# epochs =  26 , step =  400 , loss_val =  0.0053445096
# epochs =  26 , step =  500 , loss_val =  0.0047316747
# epochs =  27 , step =  0 , loss_val =  1.4981134e-05
# epochs =  27 , step =  100 , loss_val =  0.0002110613
# epochs =  27 , step =  200 , loss_val =  0.00019068156
# epochs =  27 , step =  300 , loss_val =  8.8011526e-05
# epochs =  27 , step =  400 , loss_val =  0.038647935
# epochs =  27 , step =  500 , loss_val =  4.0710085e-05
# epochs =  28 , step =  0 , loss_val =  0.00011480017
# epochs =  28 , step =  100 , loss_val =  0.000666769
# epochs =  28 , step =  200 , loss_val =  6.421174e-06
# epochs =  28 , step =  300 , loss_val =  0.0006275108
# epochs =  28 , step =  400 , loss_val =  2.236146e-06
# epochs =  28 , step =  500 , loss_val =  0.00015183803
# epochs =  29 , step =  0 , loss_val =  0.0068222224
# epochs =  29 , step =  100 , loss_val =  1.6681144e-05
# epochs =  29 , step =  200 , loss_val =  2.2245837e-05
# epochs =  29 , step =  300 , loss_val =  4.994375e-06
# epochs =  29 , step =  400 , loss_val =  0.00074272254
# epochs =  29 , step =  500 , loss_val =  0.0005582188
# epochs =  30 , step =  0 , loss_val =  4.1126575e-07
# epochs =  30 , step =  100 , loss_val =  0.0023296291
# epochs =  30 , step =  200 , loss_val =  0.00012871817
# epochs =  30 , step =  300 , loss_val =  0.0024479076
# epochs =  30 , step =  400 , loss_val =  0.09465939
# epochs =  30 , step =  500 , loss_val =  0.0141892675
# epochs =  31 , step =  0 , loss_val =  9.243566e-05
# epochs =  31 , step =  100 , loss_val =  0.00028541076
# epochs =  31 , step =  200 , loss_val =  8.857068e-05
# epochs =  31 , step =  300 , loss_val =  0.001884047
# epochs =  31 , step =  400 , loss_val =  1.4422625e-05
# epochs =  31 , step =  500 , loss_val =  0.003972847
# epochs =  32 , step =  0 , loss_val =  0.0010097874
# epochs =  32 , step =  100 , loss_val =  0.011711801
# epochs =  32 , step =  200 , loss_val =  4.291163e-06
# epochs =  32 , step =  300 , loss_val =  2.041912e-06
# epochs =  32 , step =  400 , loss_val =  1.39678195e-05
# epochs =  32 , step =  500 , loss_val =  3.180164e-06
# epochs =  33 , step =  0 , loss_val =  4.649136e-07
# epochs =  33 , step =  100 , loss_val =  0.008695999
# epochs =  33 , step =  200 , loss_val =  0.00018349243
# epochs =  33 , step =  300 , loss_val =  2.6137142e-05
# epochs =  33 , step =  400 , loss_val =  1.3040323e-05
# epochs =  33 , step =  500 , loss_val =  0.004021913
# epochs =  34 , step =  0 , loss_val =  4.5571896e-06
# epochs =  34 , step =  100 , loss_val =  0.00012151238
# epochs =  34 , step =  200 , loss_val =  0.00041283137
# epochs =  34 , step =  300 , loss_val =  3.6451381e-06
# epochs =  34 , step =  400 , loss_val =  2.8141783e-06
# epochs =  34 , step =  500 , loss_val =  1.3136005e-06
# epochs =  35 , step =  0 , loss_val =  0.006579804
# epochs =  35 , step =  100 , loss_val =  9.64043e-05
# epochs =  35 , step =  200 , loss_val =  7.7008167e-07
# epochs =  35 , step =  300 , loss_val =  2.2958345e-06
# epochs =  35 , step =  400 , loss_val =  0.0007083831
# epochs =  35 , step =  500 , loss_val =  9.0186186e-05
# epochs =  36 , step =  0 , loss_val =  1.1401459e-05
# epochs =  36 , step =  100 , loss_val =  6.353448e-06
# epochs =  36 , step =  200 , loss_val =  0.00014043714
# epochs =  36 , step =  300 , loss_val =  2.1815207e-07
# epochs =  36 , step =  400 , loss_val =  7.1669124e-06
# epochs =  36 , step =  500 , loss_val =  9.8423174e-05
# epochs =  37 , step =  0 , loss_val =  0.000118112715
# epochs =  37 , step =  100 , loss_val =  7.054161e-06
# epochs =  37 , step =  200 , loss_val =  0.00015182626
# epochs =  37 , step =  300 , loss_val =  0.0007736534
# epochs =  37 , step =  400 , loss_val =  9.303276e-06
# epochs =  37 , step =  500 , loss_val =  8.4349515e-05
# epochs =  38 , step =  0 , loss_val =  6.484334e-06
# epochs =  38 , step =  100 , loss_val =  2.3652592e-05
# epochs =  38 , step =  200 , loss_val =  0.010305025
# epochs =  38 , step =  300 , loss_val =  0.0002078952
# epochs =  38 , step =  400 , loss_val =  1.2850496e-06
# epochs =  38 , step =  500 , loss_val =  0.00017136673
# epochs =  39 , step =  0 , loss_val =  4.119828e-05
# epochs =  39 , step =  100 , loss_val =  3.805347e-05
# epochs =  39 , step =  200 , loss_val =  1.0728834e-08
# epochs =  39 , step =  300 , loss_val =  0.00018081503
# epochs =  39 , step =  400 , loss_val =  2.8167187e-06
# epochs =  39 , step =  500 , loss_val =  2.3829052e-06
# epochs =  40 , step =  0 , loss_val =  1.7618212e-06
# epochs =  40 , step =  100 , loss_val =  0.0007450781
# epochs =  40 , step =  200 , loss_val =  5.7859706e-06
# epochs =  40 , step =  300 , loss_val =  1.5198644e-05
# epochs =  40 , step =  400 , loss_val =  1.36816725e-05
# epochs =  40 , step =  500 , loss_val =  5.4991015e-06
# epochs =  41 , step =  0 , loss_val =  1.0597452e-06
# epochs =  41 , step =  100 , loss_val =  5.9219888e-06
# epochs =  41 , step =  200 , loss_val =  1.92394e-06
# epochs =  41 , step =  300 , loss_val =  4.5849465e-05
# epochs =  41 , step =  400 , loss_val =  1.7926244e-05
# epochs =  41 , step =  500 , loss_val =  2.0503839e-07
# epochs =  42 , step =  0 , loss_val =  8.344634e-08
# epochs =  42 , step =  100 , loss_val =  0.0029865021
# epochs =  42 , step =  200 , loss_val =  0.00024507524
# epochs =  42 , step =  300 , loss_val =  2.4868908e-05
# epochs =  42 , step =  400 , loss_val =  0.00020620642
# epochs =  42 , step =  500 , loss_val =  6.933478e-05
# epochs =  43 , step =  0 , loss_val =  8.901058e-06
# epochs =  43 , step =  100 , loss_val =  8.6451055e-06
# epochs =  43 , step =  200 , loss_val =  8.460379e-06
# epochs =  43 , step =  300 , loss_val =  1.5253637e-05
# epochs =  43 , step =  400 , loss_val =  2.318636e-05
# epochs =  43 , step =  500 , loss_val =  9.973772e-06
# epochs =  44 , step =  0 , loss_val =  0.00031846456
# epochs =  44 , step =  100 , loss_val =  1.9354915e-05
# epochs =  44 , step =  200 , loss_val =  4.649157e-08
# epochs =  44 , step =  300 , loss_val =  2.3007229e-07
# epochs =  44 , step =  400 , loss_val =  1.7275635e-05
# epochs =  44 , step =  500 , loss_val =  0.025474021
# epochs =  45 , step =  0 , loss_val =  2.3603317e-07
# epochs =  45 , step =  100 , loss_val =  0.00023984876
# epochs =  45 , step =  200 , loss_val =  2.5496279e-06
# epochs =  45 , step =  300 , loss_val =  0.00013605275
# epochs =  45 , step =  400 , loss_val =  8.1932645e-05
# epochs =  45 , step =  500 , loss_val =  0.000120646844
# epochs =  46 , step =  0 , loss_val =  4.707837e-06
# epochs =  46 , step =  100 , loss_val =  1.0144372e-06
# epochs =  46 , step =  200 , loss_val =  6.29824e-06
# epochs =  46 , step =  300 , loss_val =  0.00024954104
# epochs =  46 , step =  400 , loss_val =  0.0006520081
# epochs =  46 , step =  500 , loss_val =  1.9942981e-06
# epochs =  47 , step =  0 , loss_val =  3.4570675e-08
# epochs =  47 , step =  100 , loss_val =  0.001174556
# epochs =  47 , step =  200 , loss_val =  0.0013619508
# epochs =  47 , step =  300 , loss_val =  1.1563238e-07
# epochs =  47 , step =  400 , loss_val =  6.5922245e-07
# epochs =  47 , step =  500 , loss_val =  0.00047677066
# epochs =  48 , step =  0 , loss_val =  4.0165573e-06
# epochs =  48 , step =  100 , loss_val =  5.102083e-07
# epochs =  48 , step =  200 , loss_val =  0.0084410785
# epochs =  48 , step =  300 , loss_val =  1.5628056e-06
# epochs =  48 , step =  400 , loss_val =  0.00070838555
# epochs =  48 , step =  500 , loss_val =  1.7845178e-06
# epochs =  49 , step =  0 , loss_val =  2.6866835e-05
# epochs =  49 , step =  100 , loss_val =  1.6470305e-05
# epochs =  49 , step =  200 , loss_val =  7.4068826e-06
# epochs =  49 , step =  300 , loss_val =  6.556504e-08
# epochs =  49 , step =  400 , loss_val =  0.00045104494
# epochs =  49 , step =  500 , loss_val =  3.9821416e-06
#
# elapsed time =  0:02:01.975338
#
# Accuracy =  0.9906
# type(accuracy_val) =  <class 'numpy.float32'> , type(predicted_list_val) =  <class 'numpy.ndarray'> , type(index_label) =  <class 'numpy.ndarray'>
# index_label.shape =  (10000,)
# length of index_label_list =  10000
# false label count =  94
#
# length of index_label_false_list 94

# %%
print(index_label_prediction_list)
# Out:
# [[92, 9, 4], [115, 4, 9], [158, 3, 2], [247, 4, 2], [340, 5, 3], [445, 6, 0], [449, 3, 5], [497, 4, 9], [582, 8, 2], [619, 1, 8], [674, 5, 3], [691, 8, 9], [740, 4, 9], [881, 4, 9], [900, 1, 3], [924, 2, 7], [938, 3, 5], [947, 8, 9], [965, 6, 0], [1014, 6, 5], [1039, 7, 1], [1182, 6, 5], [1226, 7, 2], [1232, 9, 4], [1319, 8, 0], [1393, 5, 3], [1790, 2, 7], [1878, 8, 3], [1901, 9, 4], [2018, 1, 2], [2035, 5, 3], [2130, 4, 9], [2182, 1, 2], [2447, 4, 9], [2578, 7, 2], [2597, 5, 3], [2654, 6, 1], [2678, 4, 9], [2771, 4, 9], [2927, 3, 7], [2939, 9, 5], [2953, 3, 5], [3023, 8, 5], [3073, 1, 2], [3225, 7, 9], [3288, 4, 9], [3333, 7, 9], [3422, 6, 0], [3451, 7, 9], [3475, 3, 7], [3520, 6, 4], [3534, 4, 8], [3559, 8, 5], [3751, 7, 2], [3762, 6, 8], [3808, 7, 8], [3869, 9, 4], [4007, 7, 9], [4176, 2, 7], [4199, 7, 9], [4201, 1, 7], [4265, 4, 9], [4284, 9, 5], [4369, 9, 4], [4382, 4, 9], [4497, 8, 7], [4536, 6, 5], [4571, 6, 8], [4740, 3, 5], [5201, 4, 9], [5246, 7, 2], [5654, 7, 2], [5801, 6, 0], [5937, 5, 3], [5973, 3, 9], [5997, 5, 9], [6555, 8, 9], [6572, 1, 5], [6597, 0, 7], [6614, 2, 7], [6625, 8, 2], [6783, 1, 6], [7154, 2, 7], [7841, 3, 9], [7928, 1, 0], [8316, 7, 2], [8520, 4, 9], [8527, 4, 9], [9015, 7, 2], [9505, 7, 2], [9599, 1, 6], [9620, 9, 7], [9642, 9, 7], [9700, 2, 8]]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

false_data_index = np.random.randint(len(index_label_prediction_list))

print('len of index_label_prediction_list => ', len(index_label_prediction_list), ', false_data_index => ', false_data_index)

mnist_index = index_label_prediction_list[false_data_index][0]
label = index_label_prediction_list[false_data_index][1]
prediction = index_label_prediction_list[false_data_index][2]

title_str = 'index = ' + str(mnist_index) + ' , label = ' + str(label) + ' , prediction = ' + str(prediction)

img = test_x_data[mnist_index].reshape(28,28)


plt.title(title_str)
plt.imshow(img, cmap='gray')
plt.show()
# Out:
# len of index_label_prediction_list =>  94 , false_data_index =>  80
