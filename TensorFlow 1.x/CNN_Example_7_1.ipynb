# %% [markdown]
# ### [예제 7_1]  1 conv / 2 FC
#
# #### 1 conv, 1 flatten layer, 1 hidden layer

# %%
# colab 에서 tensorflow 1.x 실행
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime      # datetime.now() 를 이용하여 학습 경과 시간 측정

# read_data_sets() 를 통해 데이터를 객체형태로 받아오고
# one_hot 옵션을 통해 정답(label) 을 one-hot 인코딩된 형태로 받아옴

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

# mnist 데이터 셋은 train, test, validation 3개의 데이터 셋으로 구성되어 있으며.
# num_examples 값을 통해 데이터의 갯수 확인 가능함

print("\n", mnist.train.num_examples, mnist.test.num_examples, mnist.validation.num_examples)

# 데이터는 784(28x28)개의 픽셀을 가지는 이미지와
# 10(0~9)개 클래스를 가지는 one-hot 인코딩된 레이블(정답)을 가지고 있음

print("\ntrain image shape = ", np.shape(mnist.train.images))
print("train label shape = ", np.shape(mnist.train.labels))
print("test image shape = ", np.shape(mnist.test.images))
print("test label shape = ", np.shape(mnist.test.labels))
# Out:
# WARNING:tensorflow:From <ipython-input-2-37edfc5623ff>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
#  55000 10000 5000
#
# train image shape =  (55000, 784)
# train label shape =  (55000, 10)
# test image shape =  (10000, 784)
# test label shape =  (10000, 10)

# %%
# Hyper-Parameter
learning_rate = 0.001  # 학습율
epochs = 50            # 반복횟수
batch_size = 100      # 한번에 입력으로 주어지는 MNIST 개수

# %%
# 입력과 정답을 위한 플레이스홀더 정의
X = tf.placeholder(tf.float32, [None, 784])  

A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])   # image 28X28X1 (black/white)


T = tf.placeholder(tf.float32, [None, 10])

# %%
# 1번째 컨볼루션 층, 5X5X128 필터
W2 = tf.Variable(tf.random_normal([5, 5, 1, 128], stddev=0.01))  
b2 = tf.Variable(tf.constant(0.1, shape=[128]))   

# 1번째 컨볼루션 연산을 통해 28 X 28 X1  => 28 X 28 X 128 
C2 = tf.nn.conv2d(A1, W2, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z2 = tf.nn.relu(C2+b2)

# 1번째 max pooling을 통해 28 X 28 X 128  => 14 X 14 X 128 
A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 완전연결층, 14X14X128개 입력 출력은 256개 의 은닉층 개념
A2_flat = P2_flat = tf.reshape(A2, [-1, 14*14*128])

W3 = tf.Variable(tf.random_normal([14*14*128, 512], stddev=0.01))
b3 = tf.Variable(tf.random_normal([512]))

Z3 = tf.matmul(A2_flat, W3) + b3

A3 = tf.nn.relu(Z3)

# %%
# 출력층
W4 = tf.Variable(tf.random_normal([512, 10], stddev=0.01))
b4 = tf.Variable(tf.random_normal([10]))

# 출력층 선형회귀  값 Z4, 즉 softmax 에 들어가는 입력 값
Z4 = logits = tf.matmul(A3, W4) + b4

y = A4 = tf.nn.softmax(Z4)

# %%
loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z4, labels=T) )

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
# batch_size X 10 데이터에 대해 argmax를 통해 행단위로 비교함
predicted_val = tf.equal( tf.argmax(A4, 1), tf.argmax(T, 1) )

# batch_size X 10 의 True, False 를 1 또는 0 으로 변환
accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# index list 출력
accuracy_index = tf.cast(predicted_val, dtype=tf.float32)

# 예측값 처리
predicted_list = tf.argmax(A4, 1)

# %%
index_label_prediction_list = []

with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화
    
    start_time = datetime.now()
    
    for i in range(epochs):    # 50 번 반복수행
        
        total_batch = int(mnist.train.num_examples / batch_size)  # 55,000 / 100

        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
      
            loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})    
        
            if step % 100 == 0:
                print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)             
    
    end_time = datetime.now() 
    
    print("\nelapsed time = ", end_time - start_time) 
    
    # Accuracy 확인
    test_x_data = mnist.test.images    # 10000 X 784
    test_t_data = mnist.test.labels    # 10000 X 10
    
    accuracy_val, predicted_list_val, index_label = sess.run([accuracy, predicted_list, accuracy_index], feed_dict={X: test_x_data, T: test_t_data})
    
    print("\nAccuracy = ", accuracy_val)
    print("type(accuracy_val) = ", type(accuracy_val), ', type(predicted_list_val) = ', type(predicted_list_val), ', type(index_label) = ', type(index_label))
    print("index_label.shape = ", index_label.shape)
    
    index_label_list = list(index_label)
    print("length of index_label_list = ", len(index_label_list))
    print("false label count = ", index_label_list.count([0]))
        
    
    temp_list = [] 
    
    for index in range(len(index_label)):
        
        if index_label[index] == 0:
            
            temp_list.append(index)
            temp_list.append(np.argmax(test_t_data[index]))  # one-hot encoding 이므로 argmax 로 정답 추출
            temp_list.append(predicted_list_val[index])
            
            index_label_prediction_list.append(temp_list)
            
            temp_list = []
            
    print("\nlength of index_label_false_list", len(index_label_prediction_list))
# Out:
# epochs =  0 , step =  0 , loss_val =  2.9502234
# epochs =  0 , step =  100 , loss_val =  0.47684997
# epochs =  0 , step =  200 , loss_val =  0.1886849
# epochs =  0 , step =  300 , loss_val =  0.117744744
# epochs =  0 , step =  400 , loss_val =  0.10226797
# epochs =  0 , step =  500 , loss_val =  0.08977124
# epochs =  1 , step =  0 , loss_val =  0.10269767
# epochs =  1 , step =  100 , loss_val =  0.08259914
# epochs =  1 , step =  200 , loss_val =  0.06426719
# epochs =  1 , step =  300 , loss_val =  0.06789464
# epochs =  1 , step =  400 , loss_val =  0.06826701
# epochs =  1 , step =  500 , loss_val =  0.095806025
# epochs =  2 , step =  0 , loss_val =  0.04350901
# epochs =  2 , step =  100 , loss_val =  0.13146435
# epochs =  2 , step =  200 , loss_val =  0.045136847
# epochs =  2 , step =  300 , loss_val =  0.06578821
# epochs =  2 , step =  400 , loss_val =  0.028763212
# epochs =  2 , step =  500 , loss_val =  0.024713181
# epochs =  3 , step =  0 , loss_val =  0.014563176
# epochs =  3 , step =  100 , loss_val =  0.038224928
# epochs =  3 , step =  200 , loss_val =  0.014394433
# epochs =  3 , step =  300 , loss_val =  0.04849579
# epochs =  3 , step =  400 , loss_val =  0.015372694
# epochs =  3 , step =  500 , loss_val =  0.10715552
# epochs =  4 , step =  0 , loss_val =  0.026339274
# epochs =  4 , step =  100 , loss_val =  0.018162984
# epochs =  4 , step =  200 , loss_val =  0.007485428
# epochs =  4 , step =  300 , loss_val =  0.0033924708
# epochs =  4 , step =  400 , loss_val =  0.012135358
# epochs =  4 , step =  500 , loss_val =  0.0666903
# epochs =  5 , step =  0 , loss_val =  0.016864313
# epochs =  5 , step =  100 , loss_val =  0.009179104
# epochs =  5 , step =  200 , loss_val =  0.014320238
# epochs =  5 , step =  300 , loss_val =  0.0016484344
# epochs =  5 , step =  400 , loss_val =  0.037267685
# epochs =  5 , step =  500 , loss_val =  0.0017760834
# epochs =  6 , step =  0 , loss_val =  0.0011594231
# epochs =  6 , step =  100 , loss_val =  0.009248975
# epochs =  6 , step =  200 , loss_val =  0.024343476
# epochs =  6 , step =  300 , loss_val =  0.023293002
# epochs =  6 , step =  400 , loss_val =  0.0015888878
# epochs =  6 , step =  500 , loss_val =  0.054904558
# epochs =  7 , step =  0 , loss_val =  0.001005866
# epochs =  7 , step =  100 , loss_val =  0.002030724
# epochs =  7 , step =  200 , loss_val =  0.0062685306
# epochs =  7 , step =  300 , loss_val =  0.01681473
# epochs =  7 , step =  400 , loss_val =  0.064286925
# epochs =  7 , step =  500 , loss_val =  0.0027964634
# epochs =  8 , step =  0 , loss_val =  0.008591473
# epochs =  8 , step =  100 , loss_val =  0.011345181
# epochs =  8 , step =  200 , loss_val =  0.0041526444
# epochs =  8 , step =  300 , loss_val =  0.00025379148
# epochs =  8 , step =  400 , loss_val =  0.0031136286
# epochs =  8 , step =  500 , loss_val =  0.0103236055
# epochs =  9 , step =  0 , loss_val =  0.00058541744
# epochs =  9 , step =  100 , loss_val =  0.0008149081
# epochs =  9 , step =  200 , loss_val =  0.004326472
# epochs =  9 , step =  300 , loss_val =  0.00164664
# epochs =  9 , step =  400 , loss_val =  0.00923003
# epochs =  9 , step =  500 , loss_val =  0.0007124552
# epochs =  10 , step =  0 , loss_val =  0.008430001
# epochs =  10 , step =  100 , loss_val =  0.0011990578
# epochs =  10 , step =  200 , loss_val =  0.018427126
# epochs =  10 , step =  300 , loss_val =  0.0031879747
# epochs =  10 , step =  400 , loss_val =  0.0015083369
# epochs =  10 , step =  500 , loss_val =  0.006475308
# epochs =  11 , step =  0 , loss_val =  0.0015252569
# epochs =  11 , step =  100 , loss_val =  0.0006220352
# epochs =  11 , step =  200 , loss_val =  0.0027269027
# epochs =  11 , step =  300 , loss_val =  0.00034801892
# epochs =  11 , step =  400 , loss_val =  0.0011892552
# epochs =  11 , step =  500 , loss_val =  0.055090252
# epochs =  12 , step =  0 , loss_val =  0.04083581
# epochs =  12 , step =  100 , loss_val =  0.003820403
# epochs =  12 , step =  200 , loss_val =  6.682427e-05
# epochs =  12 , step =  300 , loss_val =  0.00043563067
# epochs =  12 , step =  400 , loss_val =  0.0053909994
# epochs =  12 , step =  500 , loss_val =  0.000148452
# epochs =  13 , step =  0 , loss_val =  0.0002606189
# epochs =  13 , step =  100 , loss_val =  0.008730017
# epochs =  13 , step =  200 , loss_val =  0.0010976869
# epochs =  13 , step =  300 , loss_val =  0.015810236
# epochs =  13 , step =  400 , loss_val =  0.0009603984
# epochs =  13 , step =  500 , loss_val =  0.0017213619
# epochs =  14 , step =  0 , loss_val =  0.0019243348
# epochs =  14 , step =  100 , loss_val =  0.0016122289
# epochs =  14 , step =  200 , loss_val =  0.00076930155
# epochs =  14 , step =  300 , loss_val =  0.00050192093
# epochs =  14 , step =  400 , loss_val =  0.0005358626
# epochs =  14 , step =  500 , loss_val =  0.005258143
# epochs =  15 , step =  0 , loss_val =  0.0016446458
# epochs =  15 , step =  100 , loss_val =  0.0029236884
# epochs =  15 , step =  200 , loss_val =  0.0015311299
# epochs =  15 , step =  300 , loss_val =  4.834772e-05
# epochs =  15 , step =  400 , loss_val =  0.0024782235
# epochs =  15 , step =  500 , loss_val =  0.00071082736
# epochs =  16 , step =  0 , loss_val =  4.3067826e-06
# epochs =  16 , step =  100 , loss_val =  0.0005932936
# epochs =  16 , step =  200 , loss_val =  0.0417207
# epochs =  16 , step =  300 , loss_val =  1.1612328e-05
# epochs =  16 , step =  400 , loss_val =  0.0001739769
# epochs =  16 , step =  500 , loss_val =  0.00033732757
# epochs =  17 , step =  0 , loss_val =  0.00021266086
# epochs =  17 , step =  100 , loss_val =  0.0002719953
# epochs =  17 , step =  200 , loss_val =  0.00015416602
# epochs =  17 , step =  300 , loss_val =  7.4709875e-05
# epochs =  17 , step =  400 , loss_val =  8.650446e-06
# epochs =  17 , step =  500 , loss_val =  6.322665e-05
# epochs =  18 , step =  0 , loss_val =  3.811013e-05
# epochs =  18 , step =  100 , loss_val =  2.6136278e-05
# epochs =  18 , step =  200 , loss_val =  0.021300705
# epochs =  18 , step =  300 , loss_val =  8.108088e-05
# epochs =  18 , step =  400 , loss_val =  0.00028933567
# epochs =  18 , step =  500 , loss_val =  0.0127655575
# epochs =  19 , step =  0 , loss_val =  0.00027378026
# epochs =  19 , step =  100 , loss_val =  0.0017439999
# epochs =  19 , step =  200 , loss_val =  0.0210985
# epochs =  19 , step =  300 , loss_val =  0.0045565385
# epochs =  19 , step =  400 , loss_val =  0.0030813012
# epochs =  19 , step =  500 , loss_val =  3.524132e-05
# epochs =  20 , step =  0 , loss_val =  7.007545e-06
# epochs =  20 , step =  100 , loss_val =  0.00017340622
# epochs =  20 , step =  200 , loss_val =  0.00010995614
# epochs =  20 , step =  300 , loss_val =  0.005477475
# epochs =  20 , step =  400 , loss_val =  6.24802e-05
# epochs =  20 , step =  500 , loss_val =  7.2848314e-05
# epochs =  21 , step =  0 , loss_val =  0.0002891221
# epochs =  21 , step =  100 , loss_val =  3.301673e-05
# epochs =  21 , step =  200 , loss_val =  2.0025562e-05
# epochs =  21 , step =  300 , loss_val =  5.84111e-05
# epochs =  21 , step =  400 , loss_val =  7.947933e-06
# epochs =  21 , step =  500 , loss_val =  0.0002496994
# epochs =  22 , step =  0 , loss_val =  9.051382e-06
# epochs =  22 , step =  100 , loss_val =  2.2985936e-05
# epochs =  22 , step =  200 , loss_val =  2.6173593e-05
# epochs =  22 , step =  300 , loss_val =  0.00022443023
# epochs =  22 , step =  400 , loss_val =  0.00016629504
# epochs =  22 , step =  500 , loss_val =  0.0007449341
# epochs =  23 , step =  0 , loss_val =  1.3296551e-05
# epochs =  23 , step =  100 , loss_val =  7.0094075e-07
# epochs =  23 , step =  200 , loss_val =  4.393345e-05
# epochs =  23 , step =  300 , loss_val =  1.5961872e-05
# epochs =  23 , step =  400 , loss_val =  7.386461e-06
# epochs =  23 , step =  500 , loss_val =  1.1850029e-05
# epochs =  24 , step =  0 , loss_val =  1.5422904e-05
# epochs =  24 , step =  100 , loss_val =  0.00010305997
# epochs =  24 , step =  200 , loss_val =  0.0026590927
# epochs =  24 , step =  300 , loss_val =  0.0013228736
# epochs =  24 , step =  400 , loss_val =  5.9847807e-05
# epochs =  24 , step =  500 , loss_val =  0.03927685
# epochs =  25 , step =  0 , loss_val =  0.0014212745
# epochs =  25 , step =  100 , loss_val =  0.00066770695
# epochs =  25 , step =  200 , loss_val =  0.00012809288
# epochs =  25 , step =  300 , loss_val =  6.91956e-05
# epochs =  25 , step =  400 , loss_val =  0.002896025
# epochs =  25 , step =  500 , loss_val =  1.598714e-05
# epochs =  26 , step =  0 , loss_val =  1.416377e-05
# epochs =  26 , step =  100 , loss_val =  1.45127e-05
# epochs =  26 , step =  200 , loss_val =  0.00021927565
# epochs =  26 , step =  300 , loss_val =  0.0015894005
# epochs =  26 , step =  400 , loss_val =  4.3708013e-05
# epochs =  26 , step =  500 , loss_val =  0.0035660705
# epochs =  27 , step =  0 , loss_val =  1.1200365e-05
# epochs =  27 , step =  100 , loss_val =  2.8853332e-05
# epochs =  27 , step =  200 , loss_val =  0.011330354
# epochs =  27 , step =  300 , loss_val =  2.556819e-05
# epochs =  27 , step =  400 , loss_val =  6.903998e-05
# epochs =  27 , step =  500 , loss_val =  0.027778802
# epochs =  28 , step =  0 , loss_val =  0.0013312435
# epochs =  28 , step =  100 , loss_val =  2.0395328e-06
# epochs =  28 , step =  200 , loss_val =  0.0014830404
# epochs =  28 , step =  300 , loss_val =  4.0508174e-05
# epochs =  28 , step =  400 , loss_val =  0.048374068
# epochs =  28 , step =  500 , loss_val =  0.0388177
# epochs =  29 , step =  0 , loss_val =  0.0006675195
# epochs =  29 , step =  100 , loss_val =  0.00050230627
# epochs =  29 , step =  200 , loss_val =  0.0005189157
# epochs =  29 , step =  300 , loss_val =  2.6475204e-06
# epochs =  29 , step =  400 , loss_val =  1.3446094e-06
# epochs =  29 , step =  500 , loss_val =  0.0004201746
# epochs =  30 , step =  0 , loss_val =  0.0003005294
# epochs =  30 , step =  100 , loss_val =  0.0017940627
# epochs =  30 , step =  200 , loss_val =  5.774222e-05
# epochs =  30 , step =  300 , loss_val =  0.0031586192
# epochs =  30 , step =  400 , loss_val =  5.412232e-05
# epochs =  30 , step =  500 , loss_val =  0.0015708819
# epochs =  31 , step =  0 , loss_val =  0.00012428775
# epochs =  31 , step =  100 , loss_val =  1.55191e-05
# epochs =  31 , step =  200 , loss_val =  9.548519e-07
# epochs =  31 , step =  300 , loss_val =  2.5270738e-05
# epochs =  31 , step =  400 , loss_val =  0.000304009
# epochs =  31 , step =  500 , loss_val =  0.0006699989
# epochs =  32 , step =  0 , loss_val =  4.8555463e-05
# epochs =  32 , step =  100 , loss_val =  0.0003386636
# epochs =  32 , step =  200 , loss_val =  0.000102130405
# epochs =  32 , step =  300 , loss_val =  3.5404935e-07
# epochs =  32 , step =  400 , loss_val =  1.2323896e-05
# epochs =  32 , step =  500 , loss_val =  0.0005970891
# epochs =  33 , step =  0 , loss_val =  0.023897089
# epochs =  33 , step =  100 , loss_val =  1.0227958e-06
# epochs =  33 , step =  200 , loss_val =  2.6902462e-06
# epochs =  33 , step =  300 , loss_val =  2.5067172e-06
# epochs =  33 , step =  400 , loss_val =  2.3594137e-05
# epochs =  33 , step =  500 , loss_val =  3.8938262e-05
# epochs =  34 , step =  0 , loss_val =  1.9441177e-06
# epochs =  34 , step =  100 , loss_val =  5.976391e-06
# epochs =  34 , step =  200 , loss_val =  4.9596052e-05
# epochs =  34 , step =  300 , loss_val =  3.9773877e-06
# epochs =  34 , step =  400 , loss_val =  0.019744862
# epochs =  34 , step =  500 , loss_val =  3.2424717e-07
# epochs =  35 , step =  0 , loss_val =  1.1467539e-06
# epochs =  35 , step =  100 , loss_val =  1.06248735e-05
# epochs =  35 , step =  200 , loss_val =  4.3868673e-07
# epochs =  35 , step =  300 , loss_val =  5.8402325e-06
# epochs =  35 , step =  400 , loss_val =  1.9728175e-06
# epochs =  35 , step =  500 , loss_val =  0.0070328736
# epochs =  36 , step =  0 , loss_val =  0.0084996885
# epochs =  36 , step =  100 , loss_val =  1.1167777e-05
# epochs =  36 , step =  200 , loss_val =  5.960464e-09
# epochs =  36 , step =  300 , loss_val =  0.018814392
# epochs =  36 , step =  400 , loss_val =  3.230549e-07
# epochs =  36 , step =  500 , loss_val =  1.3541655e-06
# epochs =  37 , step =  0 , loss_val =  1.926895e-05
# epochs =  37 , step =  100 , loss_val =  6.304875e-06
# epochs =  37 , step =  200 , loss_val =  1.597401e-07
# epochs =  37 , step =  300 , loss_val =  3.3974308e-07
# epochs =  37 , step =  400 , loss_val =  0.019750968
# epochs =  37 , step =  500 , loss_val =  0.002508451
# epochs =  38 , step =  0 , loss_val =  1.6700579e-06
# epochs =  38 , step =  100 , loss_val =  6.289023e-06
# epochs =  38 , step =  200 , loss_val =  6.920876e-05
# epochs =  38 , step =  300 , loss_val =  0.0001446089
# epochs =  38 , step =  400 , loss_val =  0.00021395934
# epochs =  38 , step =  500 , loss_val =  7.545781e-07
# epochs =  39 , step =  0 , loss_val =  2.6486675e-06
# epochs =  39 , step =  100 , loss_val =  6.2531304e-05
# epochs =  39 , step =  200 , loss_val =  1.2099587e-06
# epochs =  39 , step =  300 , loss_val =  0.00053680735
# epochs =  39 , step =  400 , loss_val =  0.012045022
# epochs =  39 , step =  500 , loss_val =  0.0065537393
# epochs =  40 , step =  0 , loss_val =  9.584198e-07
# epochs =  40 , step =  100 , loss_val =  2.0491395e-06
# epochs =  40 , step =  200 , loss_val =  1.9549511e-06
# epochs =  40 , step =  300 , loss_val =  5.96036e-07
# epochs =  40 , step =  400 , loss_val =  4.2438154e-07
# epochs =  40 , step =  500 , loss_val =  1.0479279e-05
# epochs =  41 , step =  0 , loss_val =  5.356025e-06
# epochs =  41 , step =  100 , loss_val =  2.661723e-06
# epochs =  41 , step =  200 , loss_val =  4.816001e-07
# epochs =  41 , step =  300 , loss_val =  6.7716196e-06
# epochs =  41 , step =  400 , loss_val =  2.6209624e-05
# epochs =  41 , step =  500 , loss_val =  6.578648e-05
# epochs =  42 , step =  0 , loss_val =  4.3663363e-06
# epochs =  42 , step =  100 , loss_val =  0.014677202
# epochs =  42 , step =  200 , loss_val =  0.0017405
# epochs =  42 , step =  300 , loss_val =  8.5102125e-05
# epochs =  42 , step =  400 , loss_val =  0.00065179117
# epochs =  42 , step =  500 , loss_val =  0.00030574278
# epochs =  43 , step =  0 , loss_val =  0.00079278514
# epochs =  43 , step =  100 , loss_val =  0.0004304842
# epochs =  43 , step =  200 , loss_val =  0.00036795367
# epochs =  43 , step =  300 , loss_val =  0.00018290225
# epochs =  43 , step =  400 , loss_val =  0.0017339385
# epochs =  43 , step =  500 , loss_val =  7.748478e-07
# epochs =  44 , step =  0 , loss_val =  8.8451475e-07
# epochs =  44 , step =  100 , loss_val =  2.120572e-06
# epochs =  44 , step =  200 , loss_val =  5.0343738e-06
# epochs =  44 , step =  300 , loss_val =  2.1099831e-07
# epochs =  44 , step =  400 , loss_val =  7.39096e-08
# epochs =  44 , step =  500 , loss_val =  6.84693e-05
# epochs =  45 , step =  0 , loss_val =  8.986105e-05
# epochs =  45 , step =  100 , loss_val =  1.9506271e-05
# epochs =  45 , step =  200 , loss_val =  7.8080114e-07
# epochs =  45 , step =  300 , loss_val =  2.3841857e-09
# epochs =  45 , step =  400 , loss_val =  2.2516529e-06
# epochs =  45 , step =  500 , loss_val =  6.6122757e-06
# epochs =  46 , step =  0 , loss_val =  3.4927731e-07
# epochs =  46 , step =  100 , loss_val =  5.066314e-06
# epochs =  46 , step =  200 , loss_val =  1.1217146e-06
# epochs =  46 , step =  300 , loss_val =  3.6954262e-07
# epochs =  46 , step =  400 , loss_val =  1.8297152e-06
# epochs =  46 , step =  500 , loss_val =  4.0531127e-08
# epochs =  47 , step =  0 , loss_val =  1.4067535e-05
# epochs =  47 , step =  100 , loss_val =  3.8742667e-07
# epochs =  47 , step =  200 , loss_val =  1.1920337e-06
# epochs =  47 , step =  300 , loss_val =  3.7532923e-06
# epochs =  47 , step =  400 , loss_val =  1.2027523e-06
# epochs =  47 , step =  500 , loss_val =  7.4265773e-07
# epochs =  48 , step =  0 , loss_val =  4.3630087e-07
# epochs =  48 , step =  100 , loss_val =  1.3947425e-07
# epochs =  48 , step =  200 , loss_val =  1.3113017e-08
# epochs =  48 , step =  300 , loss_val =  2.9335329e-06
# epochs =  48 , step =  400 , loss_val =  6.8629142e-06
# epochs =  48 , step =  500 , loss_val =  7.4860776e-07
# epochs =  49 , step =  0 , loss_val =  7.629384e-08
# epochs =  49 , step =  100 , loss_val =  9.059873e-08
# epochs =  49 , step =  200 , loss_val =  3.6120048e-07
# epochs =  49 , step =  300 , loss_val =  3.1395373e-06
# epochs =  49 , step =  400 , loss_val =  1.4424289e-07
# epochs =  49 , step =  500 , loss_val =  1.4901111e-07
#
# elapsed time =  0:02:54.762785
#
# Accuracy =  0.9923
# type(accuracy_val) =  <class 'numpy.float32'> , type(predicted_list_val) =  <class 'numpy.ndarray'> , type(index_label) =  <class 'numpy.ndarray'>
# index_label.shape =  (10000,)
# length of index_label_list =  10000
# false label count =  77
#
# length of index_label_false_list 77

# %%
# index_label_prediction_list
print(index_label_prediction_list)
# Out:
# [[115, 4, 9], [247, 4, 6], [321, 2, 7], [340, 5, 3], [445, 6, 0], [448, 9, 8], [659, 2, 1], [947, 8, 9], [1014, 6, 5], [1112, 4, 6], [1128, 3, 7], [1226, 7, 2], [1232, 9, 4], [1242, 4, 9], [1247, 9, 5], [1260, 7, 1], [1319, 8, 0], [1393, 5, 3], [1527, 1, 5], [1554, 9, 8], [1621, 0, 6], [1709, 9, 8], [1790, 2, 7], [1828, 3, 7], [1878, 8, 3], [1901, 9, 8], [2118, 6, 0], [2130, 4, 9], [2135, 6, 1], [2182, 1, 3], [2293, 9, 2], [2414, 9, 4], [2447, 4, 9], [2597, 5, 3], [2654, 6, 1], [2778, 4, 0], [2896, 8, 0], [2921, 3, 8], [2927, 3, 2], [2939, 9, 5], [2953, 3, 5], [3073, 1, 2], [3503, 9, 1], [3520, 6, 4], [3534, 4, 8], [3681, 2, 3], [3727, 8, 9], [3762, 6, 8], [3808, 7, 8], [3941, 4, 2], [4176, 2, 7], [4201, 1, 7], [4360, 5, 3], [4571, 6, 8], [4740, 3, 5], [4761, 9, 8], [4823, 9, 4], [4860, 4, 9], [5201, 4, 9], [5228, 6, 4], [5634, 2, 8], [5654, 7, 2], [5749, 8, 2], [5937, 5, 3], [5955, 3, 8], [6166, 9, 3], [6173, 9, 8], [6560, 9, 5], [6597, 0, 9], [6603, 8, 7], [8094, 2, 8], [9015, 7, 2], [9634, 0, 1], [9638, 9, 7], [9664, 2, 7], [9692, 9, 7], [9729, 5, 6]]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

false_data_index = np.random.randint(len(index_label_prediction_list))

print('len of index_label_prediction_list => ', len(index_label_prediction_list), ', false_data_index => ', false_data_index)

mnist_index = index_label_prediction_list[false_data_index][0]
label = index_label_prediction_list[false_data_index][1]
prediction = index_label_prediction_list[false_data_index][2]

title_str = 'index = ' + str(mnist_index) + ' , label = ' + str(label) + ' , prediction = ' + str(prediction)

img = test_x_data[mnist_index].reshape(28,28)


plt.title(title_str)
plt.imshow(img, cmap='gray')
plt.show()
# Out:
# len of index_label_prediction_list =>  77 , false_data_index =>  26
