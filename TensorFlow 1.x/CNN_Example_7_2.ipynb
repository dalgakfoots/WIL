# %% [markdown]
# ### [예제 7_2] 3 conv / 2 FC
#
# #### 3 conv, 1 flatten layer, 1 hidden layer

# %%
# colab 에서 tensorflow 1.x 실행
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime      # datetime.now() 를 이용하여 학습 경과 시간 측정

# read_data_sets() 를 통해 데이터를 객체형태로 받아오고
# one_hot 옵션을 통해 정답(label) 을 one-hot 인코딩된 형태로 받아옴

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

# mnist 데이터 셋은 train, test, validation 3개의 데이터 셋으로 구성되어 있으며.
# num_examples 값을 통해 데이터의 갯수 확인 가능함

print("\n", mnist.train.num_examples, mnist.test.num_examples, mnist.validation.num_examples)

# 데이터는 784(28x28)개의 픽셀을 가지는 이미지와
# 10(0~9)개 클래스를 가지는 one-hot 인코딩된 레이블(정답)을 가지고 있음

print("\ntrain image shape = ", np.shape(mnist.train.images))
print("train label shape = ", np.shape(mnist.train.labels))
print("test image shape = ", np.shape(mnist.test.images))
print("test label shape = ", np.shape(mnist.test.labels))
# Out:
# WARNING:tensorflow:From <ipython-input-2-37edfc5623ff>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
#  55000 10000 5000
#
# train image shape =  (55000, 784)
# train label shape =  (55000, 10)
# test image shape =  (10000, 784)
# test label shape =  (10000, 10)

# %%
# Hyper-Parameter
learning_rate = 0.001  # 학습율
epochs = 50            # 반복횟수
batch_size = 100      # 한번에 입력으로 주어지는 MNIST 개수

# %%
# 입력과 정답을 위한 플레이스홀더 정의
X = tf.placeholder(tf.float32, [None, 784])  

T = tf.placeholder(tf.float32, [None, 10])  

# 입력층의 출력 값. 컨볼루션 연산을 위해 reshape 시킴
A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])   # image 28 X 28 X 1 (black/white)

# %%
# 1번째 컨볼루션 층
# 3X3 크기를 가지는 32개의 필터를 적용

F2 = tf.Variable(tf.random_normal([3, 3, 1, 32], stddev=0.01))  
b2 = tf.Variable(tf.constant(0.1, shape=[32]))  

# 1번째 컨볼루션 연산을 통해 28 X 28 X1  => 28 X 28 X 32 
C2 = tf.nn.conv2d(A1, F2, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z2 = tf.nn.relu(C2+b2)

# 1번째 max pooling을 통해 28 X 28 X 32  => 14 X 14 X 32 
A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 2번째 컨볼루션 층
F3 = tf.Variable(tf.random_normal([3, 3, 32, 64], stddev=0.01))  
b3 = tf.Variable(tf.constant(0.1, shape=[64]))  

# 2번째 컨볼루션 연산을 통해 14 X 14 X 32 => 14 X 14 X 64 
C3 = tf.nn.conv2d(A2, F3, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z3 = tf.nn.relu(C3+b3)

# 2번째 max pooling을 통해 14 X 14 X 64 => 7 X 7 X 64
A3 = P3 = tf.nn.max_pool(Z3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 3번째 컨볼루션 층
F4 = tf.Variable(tf.random_normal([3, 3, 64, 128], stddev=0.01))   
b4 = tf.Variable(tf.constant(0.1, shape=[128]))  

# 3번째 컨볼루션 연산을 통해 7 X 7 X 64 => 7 X 7 X 128
C4 = tf.nn.conv2d(A3, F4, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z4 = tf.nn.relu(C4+b4)

# 3번째 max pooling을 통해 7 X 7 X 128 => 4 X 4 X 128
A4 = P4 = tf.nn.max_pool(Z4, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 4X4 크기를 가진 128개의 activation map을 flatten 시킴
A4_flat = P4_flat = tf.reshape(A4, [-1, 128*4*4])

# %%
# 출력층
W5 = tf.Variable(tf.random_normal([128*4*4, 10], stddev=0.01))
b5 = tf.Variable(tf.random_normal([10]))

# 출력층 선형회귀  값 Z5, 즉 softmax 에 들어가는 입력 값
Z5 = logits = tf.matmul(A4_flat, W5) + b5    # 선형회귀 값 Z5

y = A5 = tf.nn.softmax(Z5)

# %%
loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z5, labels=T) )

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
# batch_size X 10 데이터에 대해 argmax를 통해 행단위로 비교함
predicted_val = tf.equal( tf.argmax(A5, 1), tf.argmax(T, 1) )

# batch_size X 10 의 True, False 를 1 또는 0 으로 변환
accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# index list 출력
accuracy_index = tf.cast(predicted_val, dtype=tf.float32)

# 예측값 처리
predicted_list = tf.argmax(A5, 1)

# %%
index_label_prediction_list = []

with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화
    
    start_time = datetime.now()
    
    for i in range(epochs):    # 30 번 반복수행
        
        total_batch = int(mnist.train.num_examples / batch_size)  # 55,000 / 100

        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
      
            loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})    
        
            if step % 100 == 0:
                print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)             
    
    end_time = datetime.now() 
    
    print("\nelapsed time = ", end_time - start_time) 
    
    # Accuracy 확인
    test_x_data = mnist.test.images    # 10000 X 784
    test_t_data = mnist.test.labels    # 10000 X 10
    
    accuracy_val, predicted_list_val, index_label = sess.run([accuracy, predicted_list, accuracy_index], feed_dict={X: test_x_data, T: test_t_data})
    
    print("\nAccuracy = ", accuracy_val)
    print("type(accuracy_val) = ", type(accuracy_val), ', type(predicted_list_val) = ', type(predicted_list_val), ', type(index_label) = ', type(index_label))
    print("index_label.shape = ", index_label.shape)
    
    index_label_list = list(index_label)
    print("length of index_label_list = ", len(index_label_list))
    print("false label count = ", index_label_list.count([0]))
        
    temp_list = [] 
    
    for index in range(len(index_label)):
        
        if index_label[index] == 0:
            
            temp_list.append(index)
            temp_list.append(np.argmax(test_t_data[index]))  # one-hot encoding 이므로 argmax 로 정답 추출
            temp_list.append(predicted_list_val[index])
            
            index_label_prediction_list.append(temp_list)
            
            temp_list = []
            
    print("\nlength of index_label_false_list", len(index_label_prediction_list))
# Out:
# epochs =  0 , step =  0 , loss_val =  2.8647518
# epochs =  0 , step =  100 , loss_val =  2.1748736
# epochs =  0 , step =  200 , loss_val =  0.3623558
# epochs =  0 , step =  300 , loss_val =  0.19645679
# epochs =  0 , step =  400 , loss_val =  0.10150471
# epochs =  0 , step =  500 , loss_val =  0.057310138
# epochs =  1 , step =  0 , loss_val =  0.10766884
# epochs =  1 , step =  100 , loss_val =  0.13124107
# epochs =  1 , step =  200 , loss_val =  0.10408535
# epochs =  1 , step =  300 , loss_val =  0.080969095
# epochs =  1 , step =  400 , loss_val =  0.050356492
# epochs =  1 , step =  500 , loss_val =  0.07012074
# epochs =  2 , step =  0 , loss_val =  0.03161863
# epochs =  2 , step =  100 , loss_val =  0.03579536
# epochs =  2 , step =  200 , loss_val =  0.025202677
# epochs =  2 , step =  300 , loss_val =  0.037023634
# epochs =  2 , step =  400 , loss_val =  0.0864519
# epochs =  2 , step =  500 , loss_val =  0.019001124
# epochs =  3 , step =  0 , loss_val =  0.033253733
# epochs =  3 , step =  100 , loss_val =  0.040843997
# epochs =  3 , step =  200 , loss_val =  0.07664605
# epochs =  3 , step =  300 , loss_val =  0.105260335
# epochs =  3 , step =  400 , loss_val =  0.049161863
# epochs =  3 , step =  500 , loss_val =  0.02101852
# epochs =  4 , step =  0 , loss_val =  0.019775502
# epochs =  4 , step =  100 , loss_val =  0.039928574
# epochs =  4 , step =  200 , loss_val =  0.02686527
# epochs =  4 , step =  300 , loss_val =  0.010443066
# epochs =  4 , step =  400 , loss_val =  0.031481434
# epochs =  4 , step =  500 , loss_val =  0.013102319
# epochs =  5 , step =  0 , loss_val =  0.0030097128
# epochs =  5 , step =  100 , loss_val =  0.017491547
# epochs =  5 , step =  200 , loss_val =  0.008810417
# epochs =  5 , step =  300 , loss_val =  0.010491086
# epochs =  5 , step =  400 , loss_val =  0.011795128
# epochs =  5 , step =  500 , loss_val =  0.07775445
# epochs =  6 , step =  0 , loss_val =  0.004574175
# epochs =  6 , step =  100 , loss_val =  0.0017742836
# epochs =  6 , step =  200 , loss_val =  0.00941759
# epochs =  6 , step =  300 , loss_val =  0.007280147
# epochs =  6 , step =  400 , loss_val =  0.0020963782
# epochs =  6 , step =  500 , loss_val =  0.011750657
# epochs =  7 , step =  0 , loss_val =  0.00733565
# epochs =  7 , step =  100 , loss_val =  0.0028259468
# epochs =  7 , step =  200 , loss_val =  0.0844587
# epochs =  7 , step =  300 , loss_val =  0.02396245
# epochs =  7 , step =  400 , loss_val =  0.0010926888
# epochs =  7 , step =  500 , loss_val =  0.0047294893
# epochs =  8 , step =  0 , loss_val =  0.011885854
# epochs =  8 , step =  100 , loss_val =  0.020216037
# epochs =  8 , step =  200 , loss_val =  0.004178713
# epochs =  8 , step =  300 , loss_val =  0.00572566
# epochs =  8 , step =  400 , loss_val =  0.0005334427
# epochs =  8 , step =  500 , loss_val =  0.005200046
# epochs =  9 , step =  0 , loss_val =  0.003076612
# epochs =  9 , step =  100 , loss_val =  0.22466801
# epochs =  9 , step =  200 , loss_val =  0.0003239711
# epochs =  9 , step =  300 , loss_val =  0.013872282
# epochs =  9 , step =  400 , loss_val =  0.003053989
# epochs =  9 , step =  500 , loss_val =  0.0020596562
# epochs =  10 , step =  0 , loss_val =  0.0074802637
# epochs =  10 , step =  100 , loss_val =  0.0065427125
# epochs =  10 , step =  200 , loss_val =  0.00046020045
# epochs =  10 , step =  300 , loss_val =  0.03213575
# epochs =  10 , step =  400 , loss_val =  0.0031418223
# epochs =  10 , step =  500 , loss_val =  0.0032917708
# epochs =  11 , step =  0 , loss_val =  0.003824203
# epochs =  11 , step =  100 , loss_val =  0.0010387866
# epochs =  11 , step =  200 , loss_val =  0.0017136792
# epochs =  11 , step =  300 , loss_val =  0.005112338
# epochs =  11 , step =  400 , loss_val =  0.00017065454
# epochs =  11 , step =  500 , loss_val =  0.02907218
# epochs =  12 , step =  0 , loss_val =  0.0014261232
# epochs =  12 , step =  100 , loss_val =  0.007374932
# epochs =  12 , step =  200 , loss_val =  0.00018465219
# epochs =  12 , step =  300 , loss_val =  0.038755473
# epochs =  12 , step =  400 , loss_val =  0.0066915588
# epochs =  12 , step =  500 , loss_val =  0.006612054
# epochs =  13 , step =  0 , loss_val =  0.0095345285
# epochs =  13 , step =  100 , loss_val =  2.9044448e-05
# epochs =  13 , step =  200 , loss_val =  0.00018771843
# epochs =  13 , step =  300 , loss_val =  0.016201815
# epochs =  13 , step =  400 , loss_val =  0.00018189712
# epochs =  13 , step =  500 , loss_val =  0.0013851705
# epochs =  14 , step =  0 , loss_val =  1.7556906e-05
# epochs =  14 , step =  100 , loss_val =  6.9343485e-05
# epochs =  14 , step =  200 , loss_val =  0.00094867067
# epochs =  14 , step =  300 , loss_val =  0.016781716
# epochs =  14 , step =  400 , loss_val =  3.03155e-05
# epochs =  14 , step =  500 , loss_val =  0.00434935
# epochs =  15 , step =  0 , loss_val =  0.000116117364
# epochs =  15 , step =  100 , loss_val =  0.0007478733
# epochs =  15 , step =  200 , loss_val =  0.015343993
# epochs =  15 , step =  300 , loss_val =  0.00010441732
# epochs =  15 , step =  400 , loss_val =  0.00028208122
# epochs =  15 , step =  500 , loss_val =  0.0008793891
# epochs =  16 , step =  0 , loss_val =  0.003227381
# epochs =  16 , step =  100 , loss_val =  0.003937504
# epochs =  16 , step =  200 , loss_val =  2.6644027e-05
# epochs =  16 , step =  300 , loss_val =  0.0011661458
# epochs =  16 , step =  400 , loss_val =  0.00023328525
# epochs =  16 , step =  500 , loss_val =  0.00525922
# epochs =  17 , step =  0 , loss_val =  2.4893969e-05
# epochs =  17 , step =  100 , loss_val =  0.000120506535
# epochs =  17 , step =  200 , loss_val =  0.0023158255
# epochs =  17 , step =  300 , loss_val =  0.0011187143
# epochs =  17 , step =  400 , loss_val =  0.00025561018
# epochs =  17 , step =  500 , loss_val =  0.00047516834
# epochs =  18 , step =  0 , loss_val =  7.531681e-05
# epochs =  18 , step =  100 , loss_val =  0.005320683
# epochs =  18 , step =  200 , loss_val =  0.0018492304
# epochs =  18 , step =  300 , loss_val =  5.3047705e-05
# epochs =  18 , step =  400 , loss_val =  8.2574974e-05
# epochs =  18 , step =  500 , loss_val =  0.00061413465
# epochs =  19 , step =  0 , loss_val =  0.0018714288
# epochs =  19 , step =  100 , loss_val =  7.06847e-05
# epochs =  19 , step =  200 , loss_val =  0.0003129983
# epochs =  19 , step =  300 , loss_val =  0.0027872315
# epochs =  19 , step =  400 , loss_val =  0.0011691932
# epochs =  19 , step =  500 , loss_val =  0.00062009395
# epochs =  20 , step =  0 , loss_val =  0.00066662044
# epochs =  20 , step =  100 , loss_val =  1.8905977e-05
# epochs =  20 , step =  200 , loss_val =  1.9444318e-05
# epochs =  20 , step =  300 , loss_val =  8.3004095e-05
# epochs =  20 , step =  400 , loss_val =  4.192142e-05
# epochs =  20 , step =  500 , loss_val =  0.0009231435
# epochs =  21 , step =  0 , loss_val =  3.3182503e-05
# epochs =  21 , step =  100 , loss_val =  2.6191392e-05
# epochs =  21 , step =  200 , loss_val =  0.0003770506
# epochs =  21 , step =  300 , loss_val =  0.00013072375
# epochs =  21 , step =  400 , loss_val =  0.00017917407
# epochs =  21 , step =  500 , loss_val =  0.00033214118
# epochs =  22 , step =  0 , loss_val =  0.00018584952
# epochs =  22 , step =  100 , loss_val =  0.0024627184
# epochs =  22 , step =  200 , loss_val =  0.00014439638
# epochs =  22 , step =  300 , loss_val =  0.00036716938
# epochs =  22 , step =  400 , loss_val =  1.1349858e-05
# epochs =  22 , step =  500 , loss_val =  1.8709357e-05
# epochs =  23 , step =  0 , loss_val =  0.0007882246
# epochs =  23 , step =  100 , loss_val =  0.0005132321
# epochs =  23 , step =  200 , loss_val =  1.5959462e-05
# epochs =  23 , step =  300 , loss_val =  0.00012314059
# epochs =  23 , step =  400 , loss_val =  2.8318827e-05
# epochs =  23 , step =  500 , loss_val =  0.00018861445
# epochs =  24 , step =  0 , loss_val =  3.3917906e-05
# epochs =  24 , step =  100 , loss_val =  1.258812e-06
# epochs =  24 , step =  200 , loss_val =  3.158243e-05
# epochs =  24 , step =  300 , loss_val =  2.927633e-06
# epochs =  24 , step =  400 , loss_val =  1.2045851e-05
# epochs =  24 , step =  500 , loss_val =  0.00029718672
# epochs =  25 , step =  0 , loss_val =  0.015906485
# epochs =  25 , step =  100 , loss_val =  0.0009342091
# epochs =  25 , step =  200 , loss_val =  0.0003675595
# epochs =  25 , step =  300 , loss_val =  0.009110771
# epochs =  25 , step =  400 , loss_val =  1.3842756e-05
# epochs =  25 , step =  500 , loss_val =  0.009240931
# epochs =  26 , step =  0 , loss_val =  0.000612451
# epochs =  26 , step =  100 , loss_val =  7.0584683e-06
# epochs =  26 , step =  200 , loss_val =  0.0075434837
# epochs =  26 , step =  300 , loss_val =  0.0051097577
# epochs =  26 , step =  400 , loss_val =  0.017704833
# epochs =  26 , step =  500 , loss_val =  4.287707e-06
# epochs =  27 , step =  0 , loss_val =  0.00011813581
# epochs =  27 , step =  100 , loss_val =  0.0074589374
# epochs =  27 , step =  200 , loss_val =  1.8393877e-05
# epochs =  27 , step =  300 , loss_val =  5.8321588e-05
# epochs =  27 , step =  400 , loss_val =  2.0033547e-05
# epochs =  27 , step =  500 , loss_val =  0.010850301
# epochs =  28 , step =  0 , loss_val =  0.00016643551
# epochs =  28 , step =  100 , loss_val =  0.0005157705
# epochs =  28 , step =  200 , loss_val =  0.004513496
# epochs =  28 , step =  300 , loss_val =  0.042026922
# epochs =  28 , step =  400 , loss_val =  1.2328969e-05
# epochs =  28 , step =  500 , loss_val =  4.552319e-06
# epochs =  29 , step =  0 , loss_val =  0.00012019855
# epochs =  29 , step =  100 , loss_val =  0.0001242365
# epochs =  29 , step =  200 , loss_val =  3.8071273e-06
# epochs =  29 , step =  300 , loss_val =  5.2131712e-05
# epochs =  29 , step =  400 , loss_val =  0.005171238
# epochs =  29 , step =  500 , loss_val =  3.7143284e-06
# epochs =  30 , step =  0 , loss_val =  4.310044e-06
# epochs =  30 , step =  100 , loss_val =  1.0528675e-05
# epochs =  30 , step =  200 , loss_val =  0.00017092442
# epochs =  30 , step =  300 , loss_val =  1.9083936e-05
# epochs =  30 , step =  400 , loss_val =  2.0820864e-05
# epochs =  30 , step =  500 , loss_val =  0.0002995043
# epochs =  31 , step =  0 , loss_val =  0.0014639156
# epochs =  31 , step =  100 , loss_val =  8.234943e-05
# epochs =  31 , step =  200 , loss_val =  0.00019038496
# epochs =  31 , step =  300 , loss_val =  0.012138502
# epochs =  31 , step =  400 , loss_val =  0.0002018101
# epochs =  31 , step =  500 , loss_val =  0.003672044
# epochs =  32 , step =  0 , loss_val =  0.0036372738
# epochs =  32 , step =  100 , loss_val =  7.3677715e-05
# epochs =  32 , step =  200 , loss_val =  0.00018519511
# epochs =  32 , step =  300 , loss_val =  0.0014639188
# epochs =  32 , step =  400 , loss_val =  0.00031185962
# epochs =  32 , step =  500 , loss_val =  3.762008e-05
# epochs =  33 , step =  0 , loss_val =  3.5437308e-05
# epochs =  33 , step =  100 , loss_val =  0.00039331286
# epochs =  33 , step =  200 , loss_val =  2.8071795e-06
# epochs =  33 , step =  300 , loss_val =  0.00010105944
# epochs =  33 , step =  400 , loss_val =  0.00223536
# epochs =  33 , step =  500 , loss_val =  0.0022903855
# epochs =  34 , step =  0 , loss_val =  1.6629228e-05
# epochs =  34 , step =  100 , loss_val =  5.123029e-06
# epochs =  34 , step =  200 , loss_val =  0.00020411717
# epochs =  34 , step =  300 , loss_val =  0.00023823709
# epochs =  34 , step =  400 , loss_val =  0.0063808407
# epochs =  34 , step =  500 , loss_val =  1.2123413e-06
# epochs =  35 , step =  0 , loss_val =  0.00069609866
# epochs =  35 , step =  100 , loss_val =  1.49047755e-05
# epochs =  35 , step =  200 , loss_val =  4.2399747e-06
# epochs =  35 , step =  300 , loss_val =  0.0017859974
# epochs =  35 , step =  400 , loss_val =  0.00021167015
# epochs =  35 , step =  500 , loss_val =  0.00052243384
# epochs =  36 , step =  0 , loss_val =  2.6225865e-07
# epochs =  36 , step =  100 , loss_val =  4.768361e-08
# epochs =  36 , step =  200 , loss_val =  3.9872075e-06
# epochs =  36 , step =  300 , loss_val =  3.3613535e-06
# epochs =  36 , step =  400 , loss_val =  1.3287822e-05
# epochs =  36 , step =  500 , loss_val =  2.3933886e-05
# epochs =  37 , step =  0 , loss_val =  9.655936e-08
# epochs =  37 , step =  100 , loss_val =  6.961737e-07
# epochs =  37 , step =  200 , loss_val =  3.933901e-08
# epochs =  37 , step =  300 , loss_val =  2.2719826e-06
# epochs =  37 , step =  400 , loss_val =  3.933899e-08
# epochs =  37 , step =  500 , loss_val =  5.3166275e-07
# epochs =  38 , step =  0 , loss_val =  6.174988e-07
# epochs =  38 , step =  100 , loss_val =  1.1539138e-06
# epochs =  38 , step =  200 , loss_val =  3.3607088e-05
# epochs =  38 , step =  300 , loss_val =  7.1525563e-09
# epochs =  38 , step =  400 , loss_val =  7.5261734e-05
# epochs =  38 , step =  500 , loss_val =  2.5803125e-05
# epochs =  39 , step =  0 , loss_val =  1.0251983e-07
# epochs =  39 , step =  100 , loss_val =  1.5079081e-06
# epochs =  39 , step =  200 , loss_val =  8.177496e-07
# epochs =  39 , step =  300 , loss_val =  7.62938e-08
# epochs =  39 , step =  400 , loss_val =  5.746766e-06
# epochs =  39 , step =  500 , loss_val =  1.1601129e-05
# epochs =  40 , step =  0 , loss_val =  6.042009e-06
# epochs =  40 , step =  100 , loss_val =  2.1659484e-06
# epochs =  40 , step =  200 , loss_val =  2.1979995e-06
# epochs =  40 , step =  300 , loss_val =  2.0742216e-07
# epochs =  40 , step =  400 , loss_val =  5.7220294e-08
# epochs =  40 , step =  500 , loss_val =  1.3314814e-06
# epochs =  41 , step =  0 , loss_val =  2.5019037e-06
# epochs =  41 , step =  100 , loss_val =  4.6014262e-07
# epochs =  41 , step =  200 , loss_val =  1.3755864e-06
# epochs =  41 , step =  300 , loss_val =  1.0048935e-06
# epochs =  41 , step =  400 , loss_val =  1.8083248e-06
# epochs =  41 , step =  500 , loss_val =  3.4947516e-06
# epochs =  42 , step =  0 , loss_val =  3.2662862e-07
# epochs =  42 , step =  100 , loss_val =  1.1143262e-05
# epochs =  42 , step =  200 , loss_val =  4.827862e-07
# epochs =  42 , step =  300 , loss_val =  2.3112318e-06
# epochs =  42 , step =  400 , loss_val =  1.6747915e-06
# epochs =  42 , step =  500 , loss_val =  1.0251963e-07
# epochs =  43 , step =  0 , loss_val =  5.996151e-07
# epochs =  43 , step =  100 , loss_val =  5.9604632e-09
# epochs =  43 , step =  200 , loss_val =  7.718856e-06
# epochs =  43 , step =  300 , loss_val =  7.3669236e-07
# epochs =  43 , step =  400 , loss_val =  1.4305109e-08
# epochs =  43 , step =  500 , loss_val =  6.5045956e-06
# epochs =  44 , step =  0 , loss_val =  5.280858e-07
# epochs =  44 , step =  100 , loss_val =  2.1457668e-08
# epochs =  44 , step =  200 , loss_val =  4.1723215e-08
# epochs =  44 , step =  300 , loss_val =  1.4901075e-07
# epochs =  44 , step =  400 , loss_val =  1.7881387e-08
# epochs =  44 , step =  500 , loss_val =  1.7284532e-06
# epochs =  45 , step =  0 , loss_val =  8.1062026e-08
# epochs =  45 , step =  100 , loss_val =  1.6366813e-06
# epochs =  45 , step =  200 , loss_val =  5.7339184e-07
# epochs =  45 , step =  300 , loss_val =  2.2732397e-06
# epochs =  45 , step =  400 , loss_val =  1.08596e-06
# epochs =  45 , step =  500 , loss_val =  1.311302e-08
# epochs =  46 , step =  0 , loss_val =  4.172318e-08
# epochs =  46 , step =  100 , loss_val =  5.006786e-08
# epochs =  46 , step =  200 , loss_val =  9.774723e-07
# epochs =  46 , step =  300 , loss_val =  6.246379e-07
# epochs =  46 , step =  400 , loss_val =  2.8252217e-07
# epochs =  46 , step =  500 , loss_val =  2.208834e-06
# epochs =  47 , step =  0 , loss_val =  6.210703e-07
# epochs =  47 , step =  100 , loss_val =  2.3603182e-07
# epochs =  47 , step =  200 , loss_val =  3.3923704e-06
# epochs =  47 , step =  300 , loss_val =  1.5497202e-08
# epochs =  47 , step =  400 , loss_val =  4.0768953e-07
# epochs =  47 , step =  500 , loss_val =  8.463771e-07
# epochs =  48 , step =  0 , loss_val =  1.1920929e-09
# epochs =  48 , step =  100 , loss_val =  5.793435e-07
# epochs =  48 , step =  200 , loss_val =  4.768371e-09
# epochs =  48 , step =  300 , loss_val =  3.1947604e-07
# epochs =  48 , step =  400 , loss_val =  1.672433e-06
# epochs =  48 , step =  500 , loss_val =  6.794701e-07
# epochs =  49 , step =  0 , loss_val =  3.1351928e-07
# epochs =  49 , step =  100 , loss_val =  5.7457396e-07
# epochs =  49 , step =  200 , loss_val =  3.5762784e-09
# epochs =  49 , step =  300 , loss_val =  1.4662687e-07
# epochs =  49 , step =  400 , loss_val =  3.933901e-08
# epochs =  49 , step =  500 , loss_val =  2.3841855e-09
#
# elapsed time =  0:01:56.606411
#
# Accuracy =  0.9937
# type(accuracy_val) =  <class 'numpy.float32'> , type(predicted_list_val) =  <class 'numpy.ndarray'> , type(index_label) =  <class 'numpy.ndarray'>
# index_label.shape =  (10000,)
# length of index_label_list =  10000
# false label count =  63
#
# length of index_label_false_list 63

# %%
# index_label_prediction_list
print(index_label_prediction_list)
# Out:
# [[92, 9, 4], [247, 4, 6], [321, 2, 7], [449, 3, 5], [674, 5, 3], [740, 4, 9], [938, 3, 5], [947, 8, 9], [1014, 6, 5], [1039, 7, 1], [1226, 7, 2], [1232, 9, 4], [1247, 9, 5], [1319, 8, 0], [1393, 5, 3], [1709, 9, 5], [1878, 8, 3], [1901, 9, 4], [2070, 7, 9], [2118, 6, 0], [2129, 9, 8], [2130, 4, 9], [2135, 6, 1], [2414, 9, 4], [2488, 2, 8], [2597, 5, 3], [2654, 6, 1], [2720, 9, 4], [2742, 9, 7], [2896, 8, 0], [2927, 3, 2], [2939, 9, 5], [2953, 3, 5], [3073, 1, 2], [3422, 6, 0], [3520, 6, 4], [3808, 7, 8], [3906, 1, 3], [4007, 7, 4], [4078, 9, 8], [4369, 9, 4], [4571, 6, 8], [4740, 3, 5], [4783, 4, 9], [4814, 6, 0], [4823, 9, 4], [4838, 6, 5], [4860, 4, 9], [5936, 4, 9], [5937, 5, 3], [5997, 5, 9], [6571, 9, 7], [6576, 7, 1], [6597, 0, 7], [6651, 0, 8], [6847, 6, 4], [8094, 2, 8], [8408, 8, 5], [8520, 4, 9], [9015, 7, 2], [9664, 2, 7], [9679, 6, 1], [9729, 5, 6]]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

false_data_index = np.random.randint(len(index_label_prediction_list))

print('len of index_label_prediction_list => ', len(index_label_prediction_list), ', false_data_index => ', false_data_index)

mnist_index = index_label_prediction_list[false_data_index][0]
label = index_label_prediction_list[false_data_index][1]
prediction = index_label_prediction_list[false_data_index][2]

title_str = 'index = ' + str(mnist_index) + ' , label = ' + str(label) + ' , prediction = ' + str(prediction)

img = test_x_data[mnist_index].reshape(28,28)


plt.title(title_str)
plt.imshow(img, cmap='gray')
plt.show()
# Out:
# len of index_label_prediction_list =>  63 , false_data_index =>  40
