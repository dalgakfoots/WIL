# %% [markdown]
# [예제 4_2]
# 2 conv / 1 flatten CNN 구조를 이용하여 index_label_prediction 값을 출력하는 코드를 구현하고. 필터 개수가 변화할 때 기존 코드의 어느 부분이 변경되는지 확인하시오

# %%
# %tensorflow_version 1.x
# Out:
# TensorFlow 1.x selected.

# %%
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data
import numpy as np
from datetime import datetime      # datetime.now() 를 이용하여 학습 경과 시간 측정

# read_data_sets() 를 통해 데이터를 객체형태로 받아오고
# one_hot 옵션을 통해 정답(label) 을 one-hot 인코딩된 형태로 받아옴

mnist = input_data.read_data_sets("MNIST_data/", one_hot=True)

# mnist 데이터 셋은 train, test, validation 3개의 데이터 셋으로 구성되어 있으며.
# num_examples 값을 통해 데이터의 갯수 확인 가능함

print("\n", mnist.train.num_examples, mnist.test.num_examples, mnist.validation.num_examples)

# 데이터는 784(28x28)개의 픽셀을 가지는 이미지와
# 10(0~9)개 클래스를 가지는 one-hot 인코딩된 레이블(정답)을 가지고 있음

print("\ntrain image shape = ", np.shape(mnist.train.images))
print("train label shape = ", np.shape(mnist.train.labels))
print("test image shape = ", np.shape(mnist.test.images))
print("test label shape = ", np.shape(mnist.test.labels))
# Out:
# WARNING:tensorflow:From <ipython-input-2-37edfc5623ff>:9: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:110: dense_to_one_hot (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.one_hot on tensors.
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
#
#  55000 10000 5000
#
# train image shape =  (55000, 784)
# train label shape =  (55000, 10)
# test image shape =  (10000, 784)
# test label shape =  (10000, 10)

# %%
# Hyper-Parameter
learning_rate = 0.001  # 학습율
epochs = 50            # 반복횟수
batch_size = 100      # 한번에 입력으로 주어지는 MNIST 개수

# %%
# 입력과 정답을 위한 플레이스홀더 정의
X = tf.placeholder(tf.float32, [None, 784])  

A1 = X_img = tf.reshape(X, [-1, 28, 28, 1])   # image 28X28X1 (black/white)


T = tf.placeholder(tf.float32, [None, 10])

# %%
# 1번째 컨볼루션 층
W2 = tf.Variable(tf.random_normal([5, 5, 1, 32], stddev=0.01))  
b2 = tf.Variable(tf.constant(0.1, shape=[32]))   

# 1번째 컨볼루션 연산을 통해 28 X 28 X1  => 28 X 28 X 32 
C2 = tf.nn.conv2d(A1, W2, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z2 = tf.nn.relu(C2+b2)

# 1번째 max pooling을 통해 28 X 28 X 32  => 14 X 14 X 32 
A2 = P2 = tf.nn.max_pool(Z2, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 2번째 컨볼루션 층,  5X5X64
W3 = tf.Variable(tf.random_normal([5, 5, 32, 64], stddev=0.01))  
b3 = tf.Variable(tf.constant(0.1, shape=[64]))   

# 2번째 컨볼루션 연산을 통해 14 X 14 X 32 => 14 X 14 X 64 
C3 = tf.nn.conv2d(A2, W3, strides=[1, 1, 1, 1], padding='SAME')

# relu
Z3 = tf.nn.relu(C3+b3)

# 2번째 max pooling을 통해 14 X 14 X 64 => 7 X 7 X 64
A3 = P3 = tf.nn.max_pool(Z3, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')

# %%
# 7X7 크기를 가진 64개의 activation map을 flatten 시킴
A3_flat = P3_flat = tf.reshape(A3, [-1, 7*7*64])

# %%
# 출력층
W4 = tf.Variable(tf.random_normal([7*7*64, 10], stddev=0.01))
b4 = tf.Variable(tf.random_normal([10]))

# 출력층 선형회귀  값 Z4, 즉 softmax 에 들어가는 입력 값
Z4 = logits = tf.matmul(A3_flat, W4) + b4    # 선형회귀 값 Z4

y = A4 = tf.nn.softmax(Z4)

# %%
loss = tf.reduce_mean( tf.nn.softmax_cross_entropy_with_logits_v2(logits=Z4, labels=T) )

optimizer = tf.train.AdamOptimizer(learning_rate)

train = optimizer.minimize(loss)

# %%
# batch_size X 10 데이터에 대해 argmax를 통해 행단위로 비교함
predicted_val = tf.equal( tf.argmax(A4, 1), tf.argmax(T, 1) )

# batch_size X 10 의 True, False 를 1 또는 0 으로 변환
accuracy = tf.reduce_mean(tf.cast(predicted_val, dtype=tf.float32))

# index list 출력
accuracy_index = tf.cast(predicted_val, dtype=tf.float32)

# 예측값 처리
predicted_list = tf.argmax(A4, 1)

# %%
index_label_prediction_list = []

with  tf.Session()  as sess:
    
    sess.run(tf.global_variables_initializer())  # 변수 노드(tf.Variable) 초기화
    
    start_time = datetime.now()
    
    for i in range(epochs):    
        
        total_batch = int(mnist.train.num_examples / batch_size)  # 55,000 / 100

        for step in range(total_batch):
            
            batch_x_data, batch_t_data = mnist.train.next_batch(batch_size)
      
            loss_val, _ = sess.run([loss, train], feed_dict={X: batch_x_data, T: batch_t_data})    
        
            if step % 100 == 0:
                print("epochs = ", i, ", step = ", step, ", loss_val = ", loss_val)             
    
    end_time = datetime.now() 
    
    print("\nelapsed time = ", end_time - start_time) 
    
    # Accuracy 확인
    test_x_data = mnist.test.images    # 10000 X 784
    test_t_data = mnist.test.labels    # 10000 X 10
    
    accuracy_val, predicted_list_val, index_label = sess.run([accuracy, predicted_list, accuracy_index], feed_dict={X: test_x_data, T: test_t_data})
    
    print("\nAccuracy = ", accuracy_val)
    print("type(accuracy_val) = ", type(accuracy_val), ', type(predicted_list_val) = ', type(predicted_list_val), ', type(index_label) = ', type(index_label))
    print("index_label.shape = ", index_label.shape)
    
    index_label_list = list(index_label)
    print("length of index_label_list = ", len(index_label_list))
    print("false label count = ", index_label_list.count([0]))
        
    
    temp_list = [] 
    
    for index in range(len(index_label)):
        
        if index_label[index] == 0:
            
            temp_list.append(index)
            temp_list.append(np.argmax(test_t_data[index]))  # one-hot encoding 이므로 argmax 로 정답 추출
            temp_list.append(predicted_list_val[index])
            
            index_label_prediction_list.append(temp_list)
            
            temp_list = []
            
    print("\nlength of index_label_false_list", len(index_label_prediction_list))
# Out:
# epochs =  0 , step =  0 , loss_val =  2.7592323
# epochs =  0 , step =  100 , loss_val =  0.39665982
# epochs =  0 , step =  200 , loss_val =  0.17988023
# epochs =  0 , step =  300 , loss_val =  0.14144953
# epochs =  0 , step =  400 , loss_val =  0.113424584
# epochs =  0 , step =  500 , loss_val =  0.113757364
# epochs =  1 , step =  0 , loss_val =  0.11865421
# epochs =  1 , step =  100 , loss_val =  0.0548946
# epochs =  1 , step =  200 , loss_val =  0.10004631
# epochs =  1 , step =  300 , loss_val =  0.06466645
# epochs =  1 , step =  400 , loss_val =  0.036089614
# epochs =  1 , step =  500 , loss_val =  0.06867284
# epochs =  2 , step =  0 , loss_val =  0.016283605
# epochs =  2 , step =  100 , loss_val =  0.107715905
# epochs =  2 , step =  200 , loss_val =  0.07004365
# epochs =  2 , step =  300 , loss_val =  0.05517267
# epochs =  2 , step =  400 , loss_val =  0.067605264
# epochs =  2 , step =  500 , loss_val =  0.06393427
# epochs =  3 , step =  0 , loss_val =  0.100733206
# epochs =  3 , step =  100 , loss_val =  0.017109104
# epochs =  3 , step =  200 , loss_val =  0.0077556386
# epochs =  3 , step =  300 , loss_val =  0.003818476
# epochs =  3 , step =  400 , loss_val =  0.01751564
# epochs =  3 , step =  500 , loss_val =  0.03295848
# epochs =  4 , step =  0 , loss_val =  0.03436524
# epochs =  4 , step =  100 , loss_val =  0.002846658
# epochs =  4 , step =  200 , loss_val =  0.010659532
# epochs =  4 , step =  300 , loss_val =  0.027063685
# epochs =  4 , step =  400 , loss_val =  0.06068693
# epochs =  4 , step =  500 , loss_val =  0.007007524
# epochs =  5 , step =  0 , loss_val =  0.0072241663
# epochs =  5 , step =  100 , loss_val =  0.015560932
# epochs =  5 , step =  200 , loss_val =  0.016731383
# epochs =  5 , step =  300 , loss_val =  0.049853392
# epochs =  5 , step =  400 , loss_val =  0.007552147
# epochs =  5 , step =  500 , loss_val =  0.030912178
# epochs =  6 , step =  0 , loss_val =  0.059859768
# epochs =  6 , step =  100 , loss_val =  0.008001906
# epochs =  6 , step =  200 , loss_val =  0.03280011
# epochs =  6 , step =  300 , loss_val =  0.02827016
# epochs =  6 , step =  400 , loss_val =  0.045406155
# epochs =  6 , step =  500 , loss_val =  0.025310813
# epochs =  7 , step =  0 , loss_val =  0.0253079
# epochs =  7 , step =  100 , loss_val =  0.009464587
# epochs =  7 , step =  200 , loss_val =  0.0031216368
# epochs =  7 , step =  300 , loss_val =  0.039960016
# epochs =  7 , step =  400 , loss_val =  0.0023111673
# epochs =  7 , step =  500 , loss_val =  0.042502314
# epochs =  8 , step =  0 , loss_val =  0.0040397067
# epochs =  8 , step =  100 , loss_val =  0.019787446
# epochs =  8 , step =  200 , loss_val =  0.0023210489
# epochs =  8 , step =  300 , loss_val =  0.0045916014
# epochs =  8 , step =  400 , loss_val =  0.016741272
# epochs =  8 , step =  500 , loss_val =  0.012067655
# epochs =  9 , step =  0 , loss_val =  0.004714795
# epochs =  9 , step =  100 , loss_val =  0.0017696667
# epochs =  9 , step =  200 , loss_val =  0.0034990301
# epochs =  9 , step =  300 , loss_val =  0.0019592964
# epochs =  9 , step =  400 , loss_val =  0.012335885
# epochs =  9 , step =  500 , loss_val =  0.004357049
# epochs =  10 , step =  0 , loss_val =  0.0011372418
# epochs =  10 , step =  100 , loss_val =  0.016043138
# epochs =  10 , step =  200 , loss_val =  0.0036104461
# epochs =  10 , step =  300 , loss_val =  0.00016811723
# epochs =  10 , step =  400 , loss_val =  0.031004725
# epochs =  10 , step =  500 , loss_val =  0.0005786203
# epochs =  11 , step =  0 , loss_val =  0.006513299
# epochs =  11 , step =  100 , loss_val =  0.0055414247
# epochs =  11 , step =  200 , loss_val =  0.0011439611
# epochs =  11 , step =  300 , loss_val =  0.0067253835
# epochs =  11 , step =  400 , loss_val =  0.028099922
# epochs =  11 , step =  500 , loss_val =  0.0074033528
# epochs =  12 , step =  0 , loss_val =  0.00353265
# epochs =  12 , step =  100 , loss_val =  0.00092711416
# epochs =  12 , step =  200 , loss_val =  0.0059836265
# epochs =  12 , step =  300 , loss_val =  0.0018326397
# epochs =  12 , step =  400 , loss_val =  0.00092746684
# epochs =  12 , step =  500 , loss_val =  0.00061831076
# epochs =  13 , step =  0 , loss_val =  0.013090913
# epochs =  13 , step =  100 , loss_val =  0.0005815456
# epochs =  13 , step =  200 , loss_val =  0.00186843
# epochs =  13 , step =  300 , loss_val =  0.008449575
# epochs =  13 , step =  400 , loss_val =  0.008302892
# epochs =  13 , step =  500 , loss_val =  0.055675343
# epochs =  14 , step =  0 , loss_val =  0.00058421044
# epochs =  14 , step =  100 , loss_val =  0.011228688
# epochs =  14 , step =  200 , loss_val =  0.0042787404
# epochs =  14 , step =  300 , loss_val =  0.01840375
# epochs =  14 , step =  400 , loss_val =  0.00015407153
# epochs =  14 , step =  500 , loss_val =  0.00045455326
# epochs =  15 , step =  0 , loss_val =  0.0020788885
# epochs =  15 , step =  100 , loss_val =  0.00011953739
# epochs =  15 , step =  200 , loss_val =  0.00087893324
# epochs =  15 , step =  300 , loss_val =  0.026355052
# epochs =  15 , step =  400 , loss_val =  0.007821916
# epochs =  15 , step =  500 , loss_val =  0.0013463933
# epochs =  16 , step =  0 , loss_val =  0.0026139019
# epochs =  16 , step =  100 , loss_val =  0.00072466495
# epochs =  16 , step =  200 , loss_val =  0.0039363517
# epochs =  16 , step =  300 , loss_val =  0.0039175213
# epochs =  16 , step =  400 , loss_val =  0.00016845124
# epochs =  16 , step =  500 , loss_val =  0.00035371142
# epochs =  17 , step =  0 , loss_val =  0.0027906143
# epochs =  17 , step =  100 , loss_val =  0.0009331262
# epochs =  17 , step =  200 , loss_val =  0.013626533
# epochs =  17 , step =  300 , loss_val =  0.00043865442
# epochs =  17 , step =  400 , loss_val =  0.0018551811
# epochs =  17 , step =  500 , loss_val =  4.6288707e-05
# epochs =  18 , step =  0 , loss_val =  0.015015222
# epochs =  18 , step =  100 , loss_val =  0.01979476
# epochs =  18 , step =  200 , loss_val =  0.000754234
# epochs =  18 , step =  300 , loss_val =  1.8496714e-05
# epochs =  18 , step =  400 , loss_val =  0.0011530807
# epochs =  18 , step =  500 , loss_val =  0.009382385
# epochs =  19 , step =  0 , loss_val =  3.418711e-05
# epochs =  19 , step =  100 , loss_val =  0.005016944
# epochs =  19 , step =  200 , loss_val =  0.0023989468
# epochs =  19 , step =  300 , loss_val =  0.0022743072
# epochs =  19 , step =  400 , loss_val =  0.007059129
# epochs =  19 , step =  500 , loss_val =  5.1612164e-06
# epochs =  20 , step =  0 , loss_val =  3.0838314e-06
# epochs =  20 , step =  100 , loss_val =  6.270319e-07
# epochs =  20 , step =  200 , loss_val =  0.000104336745
# epochs =  20 , step =  300 , loss_val =  0.008484441
# epochs =  20 , step =  400 , loss_val =  0.0002039997
# epochs =  20 , step =  500 , loss_val =  0.00015572616
# epochs =  21 , step =  0 , loss_val =  0.004246794
# epochs =  21 , step =  100 , loss_val =  0.00016895052
# epochs =  21 , step =  200 , loss_val =  2.2376154e-05
# epochs =  21 , step =  300 , loss_val =  0.0068025202
# epochs =  21 , step =  400 , loss_val =  0.0006590135
# epochs =  21 , step =  500 , loss_val =  0.00023801491
# epochs =  22 , step =  0 , loss_val =  0.00035747458
# epochs =  22 , step =  100 , loss_val =  0.006287436
# epochs =  22 , step =  200 , loss_val =  0.0001004589
# epochs =  22 , step =  300 , loss_val =  0.00043061332
# epochs =  22 , step =  400 , loss_val =  0.000271865
# epochs =  22 , step =  500 , loss_val =  0.0027015272
# epochs =  23 , step =  0 , loss_val =  0.0005983978
# epochs =  23 , step =  100 , loss_val =  0.001436809
# epochs =  23 , step =  200 , loss_val =  0.0007210458
# epochs =  23 , step =  300 , loss_val =  3.0958767e-05
# epochs =  23 , step =  400 , loss_val =  0.0010047774
# epochs =  23 , step =  500 , loss_val =  0.0059255995
# epochs =  24 , step =  0 , loss_val =  8.2877974e-05
# epochs =  24 , step =  100 , loss_val =  0.00019653853
# epochs =  24 , step =  200 , loss_val =  6.716912e-05
# epochs =  24 , step =  300 , loss_val =  1.3989798e-05
# epochs =  24 , step =  400 , loss_val =  0.00042080908
# epochs =  24 , step =  500 , loss_val =  0.00036485284
# epochs =  25 , step =  0 , loss_val =  0.05597009
# epochs =  25 , step =  100 , loss_val =  0.0004271229
# epochs =  25 , step =  200 , loss_val =  3.1338952e-06
# epochs =  25 , step =  300 , loss_val =  0.014680037
# epochs =  25 , step =  400 , loss_val =  0.0010244943
# epochs =  25 , step =  500 , loss_val =  5.968383e-05
# epochs =  26 , step =  0 , loss_val =  0.009306338
# epochs =  26 , step =  100 , loss_val =  4.4099426e-05
# epochs =  26 , step =  200 , loss_val =  0.00073948235
# epochs =  26 , step =  300 , loss_val =  0.00078330614
# epochs =  26 , step =  400 , loss_val =  7.269648e-05
# epochs =  26 , step =  500 , loss_val =  0.000102357044
# epochs =  27 , step =  0 , loss_val =  0.0002645181
# epochs =  27 , step =  100 , loss_val =  1.6081764e-05
# epochs =  27 , step =  200 , loss_val =  6.427068e-05
# epochs =  27 , step =  300 , loss_val =  0.0022758553
# epochs =  27 , step =  400 , loss_val =  6.7993074e-05
# epochs =  27 , step =  500 , loss_val =  1.9055451e-05
# epochs =  28 , step =  0 , loss_val =  1.0241076e-05
# epochs =  28 , step =  100 , loss_val =  9.400844e-05
# epochs =  28 , step =  200 , loss_val =  0.00012084484
# epochs =  28 , step =  300 , loss_val =  8.97938e-06
# epochs =  28 , step =  400 , loss_val =  1.0412594e-05
# epochs =  28 , step =  500 , loss_val =  1.45107015e-05
# epochs =  29 , step =  0 , loss_val =  0.0042831944
# epochs =  29 , step =  100 , loss_val =  6.75364e-06
# epochs =  29 , step =  200 , loss_val =  0.0003727716
# epochs =  29 , step =  300 , loss_val =  3.0882213e-05
# epochs =  29 , step =  400 , loss_val =  0.00023242546
# epochs =  29 , step =  500 , loss_val =  3.8299995e-06
# epochs =  30 , step =  0 , loss_val =  4.533384e-05
# epochs =  30 , step =  100 , loss_val =  0.0004423004
# epochs =  30 , step =  200 , loss_val =  0.0009950177
# epochs =  30 , step =  300 , loss_val =  1.5985592e-06
# epochs =  30 , step =  400 , loss_val =  0.0038990942
# epochs =  30 , step =  500 , loss_val =  9.484908e-05
# epochs =  31 , step =  0 , loss_val =  0.00011322823
# epochs =  31 , step =  100 , loss_val =  0.0060900534
# epochs =  31 , step =  200 , loss_val =  3.431336e-05
# epochs =  31 , step =  300 , loss_val =  0.00017200071
# epochs =  31 , step =  400 , loss_val =  3.4807585e-05
# epochs =  31 , step =  500 , loss_val =  2.0745554e-05
# epochs =  32 , step =  0 , loss_val =  0.0008712758
# epochs =  32 , step =  100 , loss_val =  3.2405915e-05
# epochs =  32 , step =  200 , loss_val =  0.0016306037
# epochs =  32 , step =  300 , loss_val =  0.014779183
# epochs =  32 , step =  400 , loss_val =  0.0014300017
# epochs =  32 , step =  500 , loss_val =  5.933902e-05
# epochs =  33 , step =  0 , loss_val =  0.0012650011
# epochs =  33 , step =  100 , loss_val =  1.0967233e-07
# epochs =  33 , step =  200 , loss_val =  1.724827e-05
# epochs =  33 , step =  300 , loss_val =  0.00012412266
# epochs =  33 , step =  400 , loss_val =  5.7614365e-05
# epochs =  33 , step =  500 , loss_val =  9.2857945e-06
# epochs =  34 , step =  0 , loss_val =  3.776012e-06
# epochs =  34 , step =  100 , loss_val =  2.4483143e-05
# epochs =  34 , step =  200 , loss_val =  7.890195e-05
# epochs =  34 , step =  300 , loss_val =  3.625273e-05
# epochs =  34 , step =  400 , loss_val =  4.131016e-06
# epochs =  34 , step =  500 , loss_val =  2.5577816e-05
# epochs =  35 , step =  0 , loss_val =  1.4363873e-06
# epochs =  35 , step =  100 , loss_val =  2.8238471e-06
# epochs =  35 , step =  200 , loss_val =  2.3161092e-06
# epochs =  35 , step =  300 , loss_val =  3.815226e-06
# epochs =  35 , step =  400 , loss_val =  5.594167e-05
# epochs =  35 , step =  500 , loss_val =  5.078238e-07
# epochs =  36 , step =  0 , loss_val =  1.1526911e-06
# epochs =  36 , step =  100 , loss_val =  9.014844e-06
# epochs =  36 , step =  200 , loss_val =  2.095528e-06
# epochs =  36 , step =  300 , loss_val =  2.8026005e-05
# epochs =  36 , step =  400 , loss_val =  8.36811e-06
# epochs =  36 , step =  500 , loss_val =  0.09714136
# epochs =  37 , step =  0 , loss_val =  0.08141484
# epochs =  37 , step =  100 , loss_val =  1.2969582e-06
# epochs =  37 , step =  200 , loss_val =  0.0021949098
# epochs =  37 , step =  300 , loss_val =  0.02303964
# epochs =  37 , step =  400 , loss_val =  0.0023990115
# epochs =  37 , step =  500 , loss_val =  0.010293321
# epochs =  38 , step =  0 , loss_val =  0.0001047359
# epochs =  38 , step =  100 , loss_val =  3.8474027e-05
# epochs =  38 , step =  200 , loss_val =  3.905989e-06
# epochs =  38 , step =  300 , loss_val =  5.1609163e-06
# epochs =  38 , step =  400 , loss_val =  0.021309072
# epochs =  38 , step =  500 , loss_val =  3.5795965e-06
# epochs =  39 , step =  0 , loss_val =  2.7319717e-05
# epochs =  39 , step =  100 , loss_val =  4.4908553e-05
# epochs =  39 , step =  200 , loss_val =  6.348872e-06
# epochs =  39 , step =  300 , loss_val =  1.6521633e-06
# epochs =  39 , step =  400 , loss_val =  1.6917182e-05
# epochs =  39 , step =  500 , loss_val =  7.4861896e-07
# epochs =  40 , step =  0 , loss_val =  1.5091609e-06
# epochs =  40 , step =  100 , loss_val =  2.6202239e-05
# epochs =  40 , step =  200 , loss_val =  4.469066e-05
# epochs =  40 , step =  300 , loss_val =  1.8988497e-06
# epochs =  40 , step =  400 , loss_val =  3.0584626e-05
# epochs =  40 , step =  500 , loss_val =  7.2001245e-07
# epochs =  41 , step =  0 , loss_val =  4.215857e-06
# epochs =  41 , step =  100 , loss_val =  2.293928e-05
# epochs =  41 , step =  200 , loss_val =  2.924895e-05
# epochs =  41 , step =  300 , loss_val =  1.28922275e-05
# epochs =  41 , step =  400 , loss_val =  3.313988e-07
# epochs =  41 , step =  500 , loss_val =  6.09818e-06
# epochs =  42 , step =  0 , loss_val =  5.2432017e-05
# epochs =  42 , step =  100 , loss_val =  3.7431397e-07
# epochs =  42 , step =  200 , loss_val =  1.357958e-05
# epochs =  42 , step =  300 , loss_val =  9.344131e-06
# epochs =  42 , step =  400 , loss_val =  1.786839e-06
# epochs =  42 , step =  500 , loss_val =  8.8928516e-07
# epochs =  43 , step =  0 , loss_val =  8.565231e-06
# epochs =  43 , step =  100 , loss_val =  5.365938e-05
# epochs =  43 , step =  200 , loss_val =  1.2623672e-06
# epochs =  43 , step =  300 , loss_val =  8.094033e-07
# epochs =  43 , step =  400 , loss_val =  3.2621432e-05
# epochs =  43 , step =  500 , loss_val =  3.4570155e-07
# epochs =  44 , step =  0 , loss_val =  1.5400744e-06
# epochs =  44 , step =  100 , loss_val =  4.220731e-05
# epochs =  44 , step =  200 , loss_val =  2.7656208e-07
# epochs =  44 , step =  300 , loss_val =  2.3841756e-07
# epochs =  44 , step =  400 , loss_val =  9.875961e-06
# epochs =  44 , step =  500 , loss_val =  3.1590216e-07
# epochs =  45 , step =  0 , loss_val =  5.888817e-07
# epochs =  45 , step =  100 , loss_val =  1.4287778e-05
# epochs =  45 , step =  200 , loss_val =  6.791084e-05
# epochs =  45 , step =  300 , loss_val =  5.8769217e-07
# epochs =  45 , step =  400 , loss_val =  1.6533345e-06
# epochs =  45 , step =  500 , loss_val =  2.6308037e-06
# epochs =  46 , step =  0 , loss_val =  7.366998e-07
# epochs =  46 , step =  100 , loss_val =  9.988469e-06
# epochs =  46 , step =  200 , loss_val =  1.4979704e-05
# epochs =  46 , step =  300 , loss_val =  1.3070889e-05
# epochs =  46 , step =  400 , loss_val =  4.870737e-05
# epochs =  46 , step =  500 , loss_val =  9.562699e-06
# epochs =  47 , step =  0 , loss_val =  2.2076422e-06
# epochs =  47 , step =  100 , loss_val =  2.741813e-08
# epochs =  47 , step =  200 , loss_val =  3.8861515e-07
# epochs =  47 , step =  300 , loss_val =  3.52856e-07
# epochs =  47 , step =  400 , loss_val =  3.1038603e-06
# epochs =  47 , step =  500 , loss_val =  3.6119877e-07
# epochs =  48 , step =  0 , loss_val =  2.1777198e-06
# epochs =  48 , step =  100 , loss_val =  3.2279318e-06
# epochs =  48 , step =  200 , loss_val =  1.31003e-06
# epochs =  48 , step =  300 , loss_val =  9.566758e-06
# epochs =  48 , step =  400 , loss_val =  8.463839e-08
# epochs =  48 , step =  500 , loss_val =  1.5581469e-05
# epochs =  49 , step =  0 , loss_val =  4.8069764e-06
# epochs =  49 , step =  100 , loss_val =  4.400788e-06
# epochs =  49 , step =  200 , loss_val =  3.661821e-06
# epochs =  49 , step =  300 , loss_val =  1.3279689e-06
# epochs =  49 , step =  400 , loss_val =  2.0384654e-07
# epochs =  49 , step =  500 , loss_val =  1.2421036e-06
#
# elapsed time =  0:01:44.738068
#
# Accuracy =  0.9928
# type(accuracy_val) =  <class 'numpy.float32'> , type(predicted_list_val) =  <class 'numpy.ndarray'> , type(index_label) =  <class 'numpy.ndarray'>
# index_label.shape =  (10000,)
# length of index_label_list =  10000
# false label count =  72
#
# length of index_label_false_list 72

# %%
# index_label_prediction_list
print(index_label_prediction_list)
# Out:
# [[115, 4, 9], [247, 4, 2], [259, 6, 0], [321, 2, 7], [340, 5, 3], [445, 6, 0], [625, 6, 4], [659, 2, 1], [674, 5, 3], [720, 5, 8], [947, 8, 9], [1014, 6, 5], [1039, 7, 1], [1232, 9, 4], [1242, 4, 9], [1247, 9, 5], [1260, 7, 1], [1414, 9, 7], [1709, 9, 5], [1790, 2, 7], [1878, 8, 3], [1901, 9, 4], [1903, 7, 2], [2035, 5, 3], [2129, 9, 2], [2130, 4, 9], [2135, 6, 1], [2195, 7, 2], [2293, 9, 4], [2414, 9, 4], [2597, 5, 3], [2648, 9, 5], [2654, 6, 1], [2939, 9, 5], [2953, 3, 5], [2959, 2, 3], [3225, 7, 9], [3422, 6, 0], [3520, 6, 4], [3558, 5, 0], [3727, 8, 9], [3762, 6, 8], [3767, 7, 2], [3808, 7, 8], [3853, 6, 8], [4176, 2, 7], [4199, 7, 9], [4284, 9, 5], [4359, 5, 9], [4571, 6, 8], [4699, 6, 1], [4740, 3, 5], [4761, 9, 8], [4838, 6, 5], [4860, 4, 9], [5201, 4, 9], [5265, 6, 4], [5654, 7, 2], [5937, 5, 3], [5955, 3, 8], [5997, 5, 9], [6560, 9, 5], [6571, 9, 3], [6576, 7, 1], [6597, 0, 3], [6625, 8, 2], [6651, 0, 8], [8094, 2, 8], [9634, 0, 1], [9679, 6, 3], [9692, 9, 7], [9729, 5, 6]]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

false_data_index = np.random.randint(len(index_label_prediction_list))

print('len of index_label_prediction_list => ', len(index_label_prediction_list), ', false_data_index => ', false_data_index)

mnist_index = index_label_prediction_list[false_data_index][0]
label = index_label_prediction_list[false_data_index][1]
prediction = index_label_prediction_list[false_data_index][2]

title_str = 'index = ' + str(mnist_index) + ' , label = ' + str(label) + ' , prediction = ' + str(prediction)

img = test_x_data[mnist_index].reshape(28,28)


plt.title(title_str)
plt.imshow(img, cmap='gray')
plt.show()
# Out:
# len of index_label_prediction_list =>  72 , false_data_index =>  14
